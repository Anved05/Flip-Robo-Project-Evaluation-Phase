# %% [markdown]
# # Baseball Case Study

# %%
# Importing the Required Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Problem Description**

# %% [markdown]
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %% [markdown]
# **Loading Databse**

# %%
# From github link
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
# Shuffle the database
#df = df.sample(frac = 1)

# %%
#Checking the shape of data
df.shape
# Out:
# (30, 17)

# %%
#checking the column information
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# 1.	W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
# 2.	R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
# 3.	AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
# 4.	H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
# 5.	2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
# 6.	3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
# 7.	HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
# 8.	BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
# 9.	SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
# 10.	SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
# 11.	RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
# 12.	ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
# 13.	ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
# 14.	CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
# 15.	SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
# 16.	SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
# 17.	E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.

# %% [markdown]
# **Out of which the from no. 2 to 17 are the input variables and the first one is output feature**

# %%
#Checking the data types of column
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# **we can see that the datatypes of the columns are same as that of the information contained in it**

# %%
# Checking for null values 
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# **As we can see that there is no null values present in the data**

# %%
# Null value visualization
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# **this also clarifies that no null value present in database**

# %%
# Using Describe function
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# **Obeservation made**
#
#
# 1. Runs scored (R) mean is less than median by only one point a little negative skewnes is obsrved
# 2. At bat time (AB) mean is more thn median a positive skewness is observed
# 3. Hit (H)  mean is more thn median a positive skewness is observed
# 4. second bat (2B)  mean is less than median by only one point a little negative skewnes is obsrved
# 5. triple bat (3B) is normally distributed
# 6. Home run(HR)  mean is more thn median a positive skewness is observed
# 7. Base on balls (BB) mean is less than median a little negative skewnes is obsrved
# 8. Strikeout (SO) mean is less than median a little negative skewnes is obsrved
# 9. Stolen base (SB) is normally distributed
# 10. Run Average (RA) mean is less than median a negative skewnes is obsrved
# 11. Earned run (EA) mean is less than median a negative skewnes is obsrved
# 12. Earned Run Average (ERA) mean is less than median by only one point a little negative skewnes is obsrved
# 13. Complete Game (CG) mean is more thn median a positive skewness is observed
# 14. Shutout (SHO) mean is less than median by only one point a little negative skewnes is obsrved
# 15. Save (SV) mean is more than median a positive skewness is observed
# 16. Errors (E) mean is more than median a positive skewness is observed

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Checking the data skewness by using the hist plot
for i in df.columns:
    print("The histogram for ", i)
    sns.histplot(x=i, data=df, kde=True)
    plt.show()
# Out:
# The histogram for  W
# The histogram for  R
# The histogram for  AB
# The histogram for  H
# The histogram for  2B
# The histogram for  3B
# The histogram for  HR
# The histogram for  BB
# The histogram for  SO
# The histogram for  SB
# The histogram for  RA
# The histogram for  ER
# The histogram for  ERA
# The histogram for  CG
# The histogram for  SHO
# The histogram for  SV
# The histogram for  E

# %% [markdown]
# **Observations**
#
# As we can see that the input variable have little skewness that can be trated using transformation techniquesin later phases
#
# 1. Runs scored (R) mean is less than median by only one point a little negative skewnes is obsrved
# 2. At bat time (AB) mean is more than median a positive skewness is observed
# 3. Hit (H)  mean is more thn median a positive skewness is observed
# 4. second bat (2B)  mean is less than median by only one point a little negative skewnes is obsrved
# 5. triple bat (3B) is normally distributed
# 6. Home run(HR)  mean is more thn median a positive skewness is observed
# 7. Base on balls (BB) mean is less than median a little negative skewnes is obsrved
# 8. Strikeout (SO) mean is less than median a little negative skewnes is obsrved
# 9. Stolen base (SB) is normally distributed
# 10. Run Average (RA) mean is less than median a negative skewnes is obsrved
# 11. Earned run (EA) mean is less than median a negative skewnes is obsrved
# 12. Earned Run Average (ERA) mean is less than median by only one point a little negative skewnes is obsrved
# 13. Complete Game (CG) mean is more than median a positive skewness is observed
# 14. Shutout (SHO) mean is less than median by only one point a little negative skewnes is obsrved
# 15. Save (SV) mean is more than median a positive skewness is observed
# 16. Errors (E) mean is more than median a positive skewness is observed

# %% [markdown]
# **Bivariate analysis**

# %%
# Using correlation for the columns

# %%
corr_mat=df.corr()
corr_mat
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
# Plotting the correlation matrix using heatmap
plt.figure(figsize=(18,10))
sns.heatmap(corr_mat,annot =True)
# Out:
# <AxesSubplot:>

# %%
# Checking Correlation of input variables with target
corr_mat['W'].sort_values(ascending = False)
# Out:
# W      1.000000
# SV     0.666530
# BB     0.484342
# SHO    0.471805
# R      0.430751
# 2B     0.427797
# HR     0.307407
# SO     0.111850
# CG     0.080533
# H      0.037612
# AB    -0.087947
# E     -0.089485
# SB    -0.157234
# 3B    -0.251118
# ER    -0.809435
# RA    -0.812952
# ERA   -0.819600
# Name: W, dtype: float64

# %% [markdown]
# **Observations**
#
# 1. Runs scored (R) is 43% Positively Correlated with the Target (No. of Wins)
# 2. At bat or time at bat (AB) is 8.8% negatively Correlated with target (No. of wins)
# 3. Hit (H) is 3.8% Positively Correlated with the Target (No. of Wins)
# 4. second bat (2B) is 43% Positively Correlated with the Target (No. of Wins)
# 5. triple bat (3B) is 25% negatively Correlated with the Target (No. of Wins)
# 6. Home run(HR) is 31% Positively Correlated with the Target (No. of Wins)
# 7. Base on balls (BB) is 48% Positively Correlated with the Target (No. of Wins)
# 8. Strikeout (SO) is 11% Positively Correlated with the Target (No. of Wins)
# 9. Stolen base (SB) is 16% negatively Correlated with the Target (No. of Wins)
# 10. Run Average (RA) is 81% negatively Correlated with the Target (No. of Wins)
# 11. Earned run (EA) is 81% negatively Correlated with the Target (No. of Wins)
# 12. Earned Run Average (ERA) is 82% negatively Correlated with the Target (No. of Wins)
# 13. Complete Game (CG) is 8.1% Positively Correlated with the Target (No. of Wins)
# 14. Shutout (SHO) is 47% Positively Correlated with the Target (No. of Wins)
# 15. Save (SV) is 67% Positively Correlated with the Target (No. of Wins)
# 16. Errors (E) is 8.9% negatively Correlated with the Target (No. of Wins)
#
#
# **Highly Correlated Input variables-  CG, EA, ERA, SV in desscending order**
#
# **Moderatley Correlated Input Variables - BB, SHO, R, 2B, HR in desscending order**
#
# **Low Correlation -3B, SO, SB in desscending order**
#
# **Very Low Correlation exists - AB, E, CG, H**
#
# **The RA,ER,ERA are highly correlated with each other hence multicolinearity is present and have to be addressed**

# %%
# Checking skewness of the database
df.skew().sort_values(ascending=False)
# Out:
# R      1.200786
# E      0.890132
# CG     0.736845
# H      0.670254
# SV     0.657524
# SHO    0.565790
# HR     0.516441
# SB     0.479893
# AB     0.183437
# BB     0.158498
# 3B     0.129502
# ER     0.058710
# ERA    0.053331
# W      0.047089
# RA     0.045734
# SO    -0.156065
# 2B    -0.230650
# dtype: float64

# %% [markdown]
# **Observation**
# 1. R,E,CG,H,SV,SHO,HR, SB are MORE positively skewed in descending order
# 2. AB, BB, 3B less positively skewed from above
# 3. ER, ERA, RA, are very less right skewed can be trated as normal distribution only
# 4. 2B, SO are negatively skewed (left)

# %%
# Detecting Outliers by Box Plot
# Taking Box plot
plt.figure(figsize=(12,7))
df.plot(kind='box', subplots=True, layout=(3,6))
# Out:
# W         AxesSubplot(0.125,0.657941;0.110714x0.222059)
# R      AxesSubplot(0.257857,0.657941;0.110714x0.222059)
# AB     AxesSubplot(0.390714,0.657941;0.110714x0.222059)
# H      AxesSubplot(0.523571,0.657941;0.110714x0.222059)
# 2B     AxesSubplot(0.656429,0.657941;0.110714x0.222059)
# 3B     AxesSubplot(0.789286,0.657941;0.110714x0.222059)
# HR        AxesSubplot(0.125,0.391471;0.110714x0.222059)
# BB     AxesSubplot(0.257857,0.391471;0.110714x0.222059)
# SO     AxesSubplot(0.390714,0.391471;0.110714x0.222059)
# SB     AxesSubplot(0.523571,0.391471;0.110714x0.222059)
# RA     AxesSubplot(0.656429,0.391471;0.110714x0.222059)
# ER     AxesSubplot(0.789286,0.391471;0.110714x0.222059)
# ERA          AxesSubplot(0.125,0.125;0.110714x0.222059)
# CG        AxesSubplot(0.257857,0.125;0.110714x0.222059)
# SHO       AxesSubplot(0.390714,0.125;0.110714x0.222059)
# SV        AxesSubplot(0.523571,0.125;0.110714x0.222059)
# E         AxesSubplot(0.656429,0.125;0.110714x0.222059)
# ...

# %% [markdown]
# **Observations**
# ouliers are present in the Run Scored (R) and Error (E) have to be treated for removal

# %% [markdown]
# # Preprocessing of data

# %% [markdown]
# **Dropping the columns ERA and RA which are actually averages of runs scored and earned runs which were causing the multicollinearity in the problem and very highly correlated with each other**

# %%
df=df.drop(['ERA','RA'],axis=1)

# %% [markdown]
# **Removing the Outliers by z score method**

# %%
# Importing Zscore
from scipy.stats import zscore
z=np.abs(zscore(df))
z.shape
# Out:
# (30, 15)

# %%
# Setting threshold at 3 and detecting the outliers
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %% [markdown]
# As we can see that only one outliers is present in the data

# %%
# Removing the outlier 
df=df[(z<3).all(axis=1)]
df.shape
# Out:
# (29, 15)

# %%
#calculating loss
loss=(30-29)/30*100
loss
# Out:
# 3.3333333333333335

# %% [markdown]
# **Observation**
#
# 1. The total loss of data after removing the outlier is 3.33% which can be consider as very low and the outliers can be removed for further analysis
#
# 2. Conclusion: I am going to check the check the model accuracy by going with and without outlier and then I will decide whether to keep outlier or remove (because sometime outlier may carry some important information

# %% [markdown]
# **creating input variable array (x) and array for input variable as (y)**

# %% [markdown]
# **With Outliers**

# %%
# Creating input and output variable array 
x=df.drop(['W'], axis=1)
y=df['W']
print(x.shape)
print(y.shape)
# Out:
# (29, 14)
# (29,)

# %%
# Removing Skewness Using Power Transform
from sklearn.preprocessing import power_transform
x=power_transform(x, method='yeo-johnson')
x
# Out:
# array([[ 9.62543504e-01,  8.38257983e-01,  4.16333634e-16,
#          1.68518793e+00,  1.00615029e+00, -7.41927000e-01,
#         -1.60519802e+00, -2.55061247e+00,  9.36131648e-01,
#         -5.08052224e-01, -3.07098204e-01, -7.87002186e-01,
#          1.53275292e+00, -3.48265262e-01],
#        [ 2.98863300e-01, -6.92877447e-01, -2.49800181e-16,
#          1.38197902e-01,  1.18522654e+00, -1.09958425e-01,
#         -4.62095966e-01,  9.36832915e-02, -5.16377335e-01,
#          2.35800488e-01, -3.07098204e-01,  2.36736538e-01,
#          3.12020186e-01, -5.40819806e-01],
#        [-3.12105130e-01, -1.11045984e+00,  0.00000000e+00,
#          1.90738550e+00, -2.28819392e-01, -6.64354121e-01,
#          1.23209786e+00, -9.35611465e-01,  2.25038365e-01,
#         -7.52213881e-01,  2.01131531e+00, -2.52844176e-01,
#         -6.64136739e-01, -1.32612477e+00],
#        [-1.30829774e+00,  2.59829043e-01, -8.32667268e-17,
#         -8.37664770e-01, -4.32227907e-01, -8.60039342e-01,
# ...

# %%
#checking for skewness is removed or not
skew_df=pd.DataFrame(x)
skew_df.skew()
# Out:
# 0    -0.024842
# 1     0.081092
# 2     0.000000
# 3    -0.052793
# 4    -0.075139
# 5     0.000448
# 6    -0.008572
# 7     0.051530
# 8    -0.009570
# 9    -0.004988
# 10   -0.045947
# 11    0.000529
# 12   -0.000925
# 13    0.065585
# dtype: float64

# %% [markdown]
# **As we can see that the Skewness is removed from the data can be processed further**

# %%
#scaling the data
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)
x
# Out:
# array([[ 9.62543504e-01,  8.39431267e-01,  1.65963137e+00,
#          1.68518793e+00,  1.00615029e+00, -7.41927000e-01,
#         -1.60519802e+00, -2.55061247e+00,  9.36131648e-01,
#         -5.08052224e-01, -3.07098204e-01, -7.87002186e-01,
#          1.53275292e+00, -3.48265262e-01],
#        [ 2.98863300e-01, -6.91704164e-01, -9.59650790e-01,
#          1.38197902e-01,  1.18522654e+00, -1.09958425e-01,
#         -4.62095966e-01,  9.36832915e-02, -5.16377335e-01,
#          2.35800488e-01, -3.07098204e-01,  2.36736538e-01,
#          3.12020186e-01, -5.40819806e-01],
#        [-3.12105130e-01, -1.10928655e+00,  2.25800186e-02,
#          1.90738550e+00, -2.28819392e-01, -6.64354121e-01,
#          1.23209786e+00, -9.35611465e-01,  2.25038365e-01,
#         -7.52213881e-01,  2.01131531e+00, -2.52844176e-01,
#         -6.64136739e-01, -1.32612477e+00],
#        [-1.30829774e+00,  2.61002327e-01, -3.04830251e-01,
#         -8.37664770e-01, -4.32227907e-01, -8.60039342e-01,
# ...

# %%
#importing the VIF in jupyter
from statsmodels.stats.outliers_influence import variance_inflation_factor
new_df=pd.DataFrame(x)
def vif_scores(df):
    VIF_Scores = pd.DataFrame()
    VIF_Scores["Independent Features"] = new_df.columns
    VIF_Scores["VIF Scores"] = [variance_inflation_factor(new_df.values,i) for i in range(new_df.shape[1])]
    return VIF_Scores
df1 = new_df
vif_scores(df1)
# Out:
#     Independent Features  VIF Scores
# 0                      0    5.506621
# 1                      1    4.888443
# 2                      2    7.395903
# 3                      3    3.099759
# 4                      4    2.929237
# 5                      5    5.528264
# 6                      6    2.954026
# 7                      7    2.293427
# 8                      8    1.945650
# 9                      9    4.480941
# 10                    10    2.324287
# 11                    11    3.070306
# 12                    12    2.242309
# 13                    13    1.978270

# %% [markdown]
# **observation Earlier before dropping the said columns**
# 1. As we can see that the VIF score of RA, ER, ERA is very high on the other hand the correlation with the output variable is also more than 80% which signifies a strong bond.
#
# **I have removed ERA and RA as they are averages of R and ER**
#
# **I have decided to proceed further because the VIFs of all columns were observed to be less than 10**

# %% [markdown]
# # Modelling the data

# %% [markdown]
# As  we can say that the target coumn has no. of wins in match can be treated as the resgression problem

# %%
# importing Linear Regression and metrics for it
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split

# %%
# Finding the best Random State
maxr2=0
maxrs=0
lr=LinearRegression()
for i in range(0,200):
    print("Random State is ", i)
    xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.20,random_state=i)
    lr.fit(xtrain,ytrain)
    predtrain=lr.predict(xtrain)
    predtest=lr.predict(xtest)
    print('training accuracy is ', r2_score(ytrain,predtrain))
    score=r2_score(ytest,predtest)
    print('testing accuracy is ', score)
    print("\n")
    
    if score>maxr2:
        maxr2=score
        maxrs=i
        
        
print("maximum r2 score is ", maxr2 , "at random state ", maxrs)
# Out:
# Random State is  0
# training accuracy is  0.9707709582492272
# testing accuracy is  0.4670912556002724
#
#
# Random State is  1
# training accuracy is  0.9511971576454311
# testing accuracy is  0.7811808261449045
#
#
# Random State is  2
# training accuracy is  0.9458987598908066
# testing accuracy is  -0.05283782515362123
#
#
# Random State is  3
# training accuracy is  0.9386899299394704
# testing accuracy is  0.8503001209042461
#
#
# Random State is  4
# training accuracy is  0.9540088262322353
# testing accuracy is  0.7362500318635286
#
#
# Random State is  5
# training accuracy is  0.9580400654724414
# testing accuracy is  0.4128168033928096
#
#
# Random State is  6
# training accuracy is  0.9216363851973992
# testing accuracy is  0.967142766337735
#
#
# Random State is  7
# training accuracy is  0.9524565103199835
# testing accuracy is  0.576493448878544
#
#
# Random State is  8
# training accuracy is  0.96855797360091
# testing accuracy is  0.7444852001090139
#
#
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=47)

# %%
#running that same model again for other metrics too

lr.fit(x_train,y_train)
predtrainlr=lr.predict(x_train)
predtestlr=lr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainlr))
print('testing accuracy is ', r2_score(y_test,predtestlr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestlr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestlr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestlr)))
# Out:
# training accuracy is  0.922442929057301
# testing accuracy is  0.990988795141837
# Mean Squared Error is  1.1374143020970096
# Mean Absolute Error is  0.9337755905623707
# Root Mean Squared Error is  1.0664962738317512

# %%
from sklearn.model_selection import cross_val_score
#Cross validation of the lr model
for j in range(2,10):
    cv_score=cross_val_score(lr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
    print('training accuracy is ', r2_score(y_train,predtrainlr))
    print('testing accuracy is ', r2_score(y_test,predtestlr))
# Out:
# At fold  2 Mean CV score is  -6.665522070325676
# training accuracy is  0.922442929057301
# testing accuracy is  0.990988795141837
# At fold  3 Mean CV score is  0.27574769654511105
# training accuracy is  0.922442929057301
# testing accuracy is  0.990988795141837
# At fold  4 Mean CV score is  0.3607371959155094
# training accuracy is  0.922442929057301
# testing accuracy is  0.990988795141837
# At fold  5 Mean CV score is  0.3396895224337146
# training accuracy is  0.922442929057301
# testing accuracy is  0.990988795141837
# At fold  6 Mean CV score is  0.2865460835275941
# training accuracy is  0.922442929057301
# testing accuracy is  0.990988795141837
# At fold  7 Mean CV score is  0.12010911036272565
# training accuracy is  0.922442929057301
# testing accuracy is  0.990988795141837
# At fold  8 Mean CV score is  0.3159180716299209
# training accuracy is  0.922442929057301
# testing accuracy is  0.990988795141837
# At fold  9 Mean CV score is  -7.001757057881626
# ...

# %% [markdown]
# **Data is only having 30 rows which is too less for cross validation hence that score is less**

# %%
# modelling using the Decision tree regressor
from sklearn.tree import DecisionTreeRegressor

dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
predtraindtr=dtr.predict(x_train)
predtestdtr=dtr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtraindtr))
print('testing accuracy is ', r2_score(y_test,predtestdtr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestdtr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestdtr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestdtr)))
# Out:
# training accuracy is  1.0
# testing accuracy is  0.778169014084507
# Mean Squared Error is  28.0
# Mean Absolute Error is  5.0
# Root Mean Squared Error is  5.291502622129181

# %%
#Cross validation of the dtr model
dtr=DecisionTreeRegressor()
for j in range(2,10):
    cvdtr=cross_val_score(dtr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cvdtr.mean())
# Out:
# At fold  2 Mean CV score is  -0.44229357403992897
# At fold  3 Mean CV score is  -0.6953733503270128
# At fold  4 Mean CV score is  -0.2739259192021217
# At fold  5 Mean CV score is  -2.5193460501402467
# At fold  6 Mean CV score is  -1.2118521755125855
# At fold  7 Mean CV score is  -1.6492081848991795
# At fold  8 Mean CV score is  -2.058876854709626
# At fold  9 Mean CV score is  -11.869993614312314

# %%
from sklearn.ensemble import RandomForestRegressor

rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
predtrainrfr=rfr.predict(x_train)
predtestrfr=rfr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainrfr))
print('testing accuracy is ', r2_score(y_test,predtestrfr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestrfr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestrfr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestrfr)))
# Out:
# training accuracy is  0.9364783845916081
# testing accuracy is  0.7596590669014083
# Mean Squared Error is  30.33636666666669
# Mean Absolute Error is  4.953333333333336
# Root Mean Squared Error is  5.507845918929349

# %%
#Cross validation of the rfr model
for j in range(2,10):
    cv_score=cross_val_score(rfr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  -0.12667797021447713
# At fold  3 Mean CV score is  -0.24557466567781186
# At fold  4 Mean CV score is  0.474803132574788
# At fold  5 Mean CV score is  -0.5624214515834802
# At fold  6 Mean CV score is  -0.34510766834407125
# At fold  7 Mean CV score is  -0.18216913975076385
# At fold  8 Mean CV score is  -0.37925734175638287
# At fold  9 Mean CV score is  -12.665141147985548

# %%
# Modelling with SVR

from sklearn.svm import SVR

svr=SVR()
svr.fit(x_train,y_train)
predtrainsvr=svr.predict(x_train)
predtestsvr=svr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainsvr))
print('testing accuracy is ', r2_score(y_test,predtestsvr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestsvr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestsvr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestsvr)))
# Out:
# training accuracy is  0.2104376458921291
# testing accuracy is  0.0963214537944469
# Mean Squared Error is  114.06431427661204
# Mean Absolute Error is  8.931637379497289
# Root Mean Squared Error is  10.680089619315563

# %%
#Cross validation of the svr model
for j in range(2,10):
    cv_score=cross_val_score(svr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  -0.19980024058598178
# At fold  3 Mean CV score is  -0.21163534309737594
# At fold  4 Mean CV score is  -0.07746519815052574
# At fold  5 Mean CV score is  -0.3175835718355847
# At fold  6 Mean CV score is  -0.1547344311728132
# At fold  7 Mean CV score is  -0.2551810628337133
# At fold  8 Mean CV score is  -0.5199521754518972
# At fold  9 Mean CV score is  -24.213495961434827

# %%
# Modeling for gradient boosting regresssor
from sklearn.ensemble import GradientBoostingRegressor

gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
predtraingbr=gbr.predict(x_train)
predtestgbr=gbr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtraingbr))
print('testing accuracy is ', r2_score(y_test,predtestgbr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestgbr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestgbr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestgbr)))
# Out:
# training accuracy is  0.9999999378198996
# testing accuracy is  0.7955865531469042
# Mean Squared Error is  25.801519513901876
# Mean Absolute Error is  4.396720972053181
# Root Mean Squared Error is  5.07951961448146

# %%
#Cross validation of the gbr model
for j in range(2,10):
    cv_score=cross_val_score(gbr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  -0.1834529759459363
# At fold  3 Mean CV score is  -0.3254443310148915
# At fold  4 Mean CV score is  0.3777174133037303
# At fold  5 Mean CV score is  -1.301140269518268
# At fold  6 Mean CV score is  -0.6754412528358605
# At fold  7 Mean CV score is  -0.5098052313016623
# At fold  8 Mean CV score is  -0.8618710010935363
# At fold  9 Mean CV score is  -7.925961652650648

# %%
from sklearn.linear_model import Lasso,Ridge, ElasticNet
from sklearn.model_selection import GridSearchCV

# %%
# Doing Lasso Regularization
#HyperParameter Tunning to find out the best parameters
parameters={'alpha':[.00001,0.0001,0.001,0.01,0.1,1,10,100],
            'random_state':list(range(0,10)),
            'max_iter':[10,100,1000,10000],
            'tol': [0.001,0.0001,0.00001,0.000001]}

ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 1, 'max_iter': 10, 'random_state': 0, 'tol': 0.001}

# %%
ls=Lasso(alpha=1, max_iter=10, random_state=0, tol=0.001)
ls.fit(x_train,y_train)
predtrainls=ls.predict(x_train)
predtestls=ls.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainls))
print('testing accuracy is ', r2_score(y_test,predtestls))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestls))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestls))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestls)))
# Out:
# training accuracy is  0.8732286239499474
# testing accuracy is  0.9319283804758981
# Mean Squared Error is  8.592151086597754
# Mean Absolute Error is  2.5385160928093833
# Root Mean Squared Error is  2.9312371256173995

# %%
#Cross validation of the ls model
for j in range(2,10):
    cv_score=cross_val_score(ls, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  0.6993613496788448
# At fold  3 Mean CV score is  0.6746530060547499
# At fold  4 Mean CV score is  0.7655824695008651
# At fold  5 Mean CV score is  0.5310148979370665
# At fold  6 Mean CV score is  0.6125851619951961
# At fold  7 Mean CV score is  0.47569616906733714
# At fold  8 Mean CV score is  0.5625290007548484
# At fold  9 Mean CV score is  -3.3737125461159945

# %%
# Doing Ridge Regularization
#HyperParameter Tunning to find out the best parameters
parameters={'alpha':[.00001,0.0001,0.001,0.01,0.1,1,10,100],
            'random_state':list(range(0,10)),
            'max_iter':[10,100,1000,10000],
            'solver':['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs']}

rg=Ridge()
clf=GridSearchCV(rg,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 1, 'max_iter': 10, 'random_state': 6, 'solver': 'sag'}

# %%
rg=Ridge(alpha=1, max_iter=10, random_state=6, solver='sag')
rg.fit(x_train,y_train)
predtrainrg=rg.predict(x_train)
predtestrg=rg.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainrg))
print('testing accuracy is ', r2_score(y_test,predtestrg))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestrg))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestrg))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestrg)))
# Out:
# training accuracy is  0.6841917364541399
# testing accuracy is  0.7555470248809659
# Mean Squared Error is  30.855397748358072
# Mean Absolute Error is  4.758723813574456
# Root Mean Squared Error is  5.554763518670986

# %%
#Cross validation of the ls model
for j in range(2,10):
    cv_score=cross_val_score(rg, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  0.5933750909263674
# At fold  3 Mean CV score is  0.5471999430755325
# At fold  4 Mean CV score is  0.6345051491321603
# At fold  5 Mean CV score is  0.55094853665017
# At fold  6 Mean CV score is  0.31582330954519966
# At fold  7 Mean CV score is  0.13731674697859048
# At fold  8 Mean CV score is  0.34290617350664115
# At fold  9 Mean CV score is  -12.47215634197038

# %%
# Doing ElasticNet regularization 
#HyperParameter Tunning to find out the best parameters
parameters={'alpha':[.00001,0.0001,0.001,0.01,0.1,1,10,100],
            'random_state':list(range(0,10)),
            'max_iter':[10,100,1000,10000],
            'tol': [0.001,0.0001,0.00001,0.000001],
            'l1_ratio': [0,0.3,0.5,0.7,1]}

en=ElasticNet()
clf=GridSearchCV(en,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 1, 'l1_ratio': 1, 'max_iter': 10, 'random_state': 0, 'tol': 0.001}

# %%
en=ElasticNet(alpha=1,random_state=0 , max_iter=10, tol=0.001, l1_ratio=1)
en.fit(x_train,y_train)
predtrainen=rg.predict(x_train)
predtesten=rg.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainen))
print('testing accuracy is ', r2_score(y_test,predtesten))
print("Mean Squared Error is ",mean_squared_error(y_test,predtesten))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtesten))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtesten)))
# Out:
# training accuracy is  0.6841917364541399
# testing accuracy is  0.7555470248809659
# Mean Squared Error is  30.855397748358072
# Mean Absolute Error is  4.758723813574456
# Root Mean Squared Error is  5.554763518670986

# %%
#Cross validation of the ElasticNet model
for j in range(2,10):
    cv_score=cross_val_score(en, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  0.6993613496788448
# At fold  3 Mean CV score is  0.6746530060547499
# At fold  4 Mean CV score is  0.7655824695008651
# At fold  5 Mean CV score is  0.5310148979370665
# At fold  6 Mean CV score is  0.6125851619951961
# At fold  7 Mean CV score is  0.47569616906733714
# At fold  8 Mean CV score is  0.5625290007548484
# At fold  9 Mean CV score is  -3.3737125461159945

# %% [markdown]
# **Observation**
# 1. I am Comparing the Cross val score at fold 4 for each model it is seen that the cross val score for the all models at fold 4 is giving higher values
#
# 2. Hence selecting on the basis of fold 4 and training and testing accuracy of Linear regression 92 and 99 respectively which is sound good
#
# 3. Model is behaving well for the linear regression and lasso, ridge and elasticnet also but out of all that the linear regression is giving good accuracy, hence selecting that for saving the model

# %% [markdown]
# **There are no Hyper parameters for the Linear Regression model, Hence skipping that step**

# %% [markdown]
# **Saving the Model**

# %%
#Importing Job lib for saving the model
import joblib
joblib.dump(LinearRegression(), "Baseball Win Prediction.pkl")
# Out:
# ['Baseball Win Prediction.pkl']

# %%
a=np.array(y_test)
predicted=np.array(predtestlr)
df_con=pd.DataFrame({'Original':a,'Predicted':predtestlr}, index=range(len(a)))
df_con
# Out:
#    Original  Predicted
# 0       100  98.934129
# 1        76  75.456476
# 2        74  74.174655
# 3        86  86.858100
# 4        76  77.131069
# 5        64  62.170566

# %% [markdown]
# **From above it is clear that the model is predicting the same output as that of the y_test**
#
# Hence we can conclude that the modelis well fitted to data
