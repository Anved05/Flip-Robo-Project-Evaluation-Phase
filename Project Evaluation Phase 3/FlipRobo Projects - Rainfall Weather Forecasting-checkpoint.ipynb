# %% [markdown]
# # Rainfall weather forecasting

# %% [markdown]
# **Project Description**
#
# Weather forecasting is the application of science and technology to predict the conditions of the atmosphere for a given location and time. Weather forecasts are made by collecting quantitative data about the current state of the atmosphere at a given place and using meteorology to project how the atmosphere will change.
# Rain Dataset is to predict whether or not it will rain tomorrow. The Dataset contains about 10 years of daily weather observations of different locations in Australia

# %% [markdown]
# **Problem Definition**
#
# 1. Design a predictive model with the use of machine learning algorithms to forecast whether or not it will rain tomorrow.
# 2. Design a predictive model with the use of machine learning algorithms to predict how much rainfall could be there.

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
# To see all columns in the dataset
pd.set_option('display.max_columns', None)

# %%
# Loading the dataset
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset3/main/weatherAUS.csv")
df
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1     2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2     2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3     2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4     2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
#      WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 0              W           44.0          W        WNW          20.0
# 1            WNW           44.0        NNW        WSW           4.0
# 2            WSW           46.0          W        WSW          19.0
# 3             NE           24.0         SE          E          11.0
# 4              W           41.0        ENE         NW           7.0
# ...          ...            ...        ...        ...           ...
# 8420           E           31.0         SE        ENE          13.0
# 8421         NNW           22.0         SE          N          13.0
# 8422           N           37.0         SE        WNW           9.0
# 8423          SE           28.0        SSE          N          13.0
# 8424         NaN            NaN        ESE        ESE          17.0
#
#       WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 0             24.0         71.0         22.0       1007.7       1007.1
# 1             22.0         44.0         25.0       1010.6       1007.8
# 2             26.0         38.0         30.0       1007.6       1008.7
# 3              9.0         45.0         16.0       1017.6       1012.8
# 4             20.0         82.0         33.0       1010.8       1006.0
# ...            ...          ...          ...          ...          ...
# 8420          11.0         51.0         24.0       1024.6       1020.3
# 8421           9.0         56.0         21.0       1023.5       1019.1
# 8422           9.0         53.0         24.0       1021.0       1016.8
# 8423           7.0         51.0         24.0       1019.4       1016.5
# 8424          17.0         62.0         36.0       1020.2       1017.9
#
#       Cloud9am  Cloud3pm  Temp9am  Temp3pm RainToday RainTomorrow
# 0          8.0       NaN     16.9     21.8        No           No
# 1          NaN       NaN     17.2     24.3        No           No
# 2          NaN       2.0     21.0     23.2        No           No
# 3          NaN       NaN     18.1     26.5        No           No
# 4          7.0       8.0     17.8     29.7        No           No
# ...        ...       ...      ...      ...       ...          ...
# 8420       NaN       NaN     10.1     22.4        No           No
# 8421       NaN       NaN     10.9     24.5        No           No
# 8422       NaN       NaN     12.5     26.1        No           No
# 8423       3.0       2.0     15.1     26.0        No           No
# 8424       8.0       8.0     15.0     20.9        No          NaN
#
# [8425 rows x 23 columns]

# %%
# checking the Attributes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   object
#  1   Location       8425 non-null   object
#  2   MinTemp        8350 non-null   float64
#  3   MaxTemp        8365 non-null   float64
#  4   Rainfall       8185 non-null   float64
#  5   Evaporation    4913 non-null   float64
#  6   Sunshine       4431 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  7434 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8349 non-null   float64
#  12  WindSpeed3pm   8318 non-null   float64
#  13  Humidity9am    8366 non-null   float64
#  14  Humidity3pm    8323 non-null   float64
#  15  Pressure9am    7116 non-null   float64
#  16  Pressure3pm    7113 non-null   float64
#  17  Cloud9am       6004 non-null   float64
#  18  Cloud3pm       5970 non-null   float64
#  19  Temp9am        8369 non-null   float64
#  20  Temp3pm        8329 non-null   float64
#  21  RainToday      8185 non-null   object
#  22  RainTomorrow   8186 non-null   object
# dtypes: float64(16), object(7)
# memory usage: 1.5+ MB

# %% [markdown]
# **Observation**
# 1. There are 8425 rows and 25 columns
# 2. there are 7 columns with categorical data and remaining are numeric columns
# 3. As we can see that there are multiple columns having the null values and to be imputed

# %%
#Estimating the null values in percentage in the database
(df.isnull().sum()/len(df)*100).sort_values(ascending=False)
# Out:
# Sunshine         47.406528
# Evaporation      41.685460
# Cloud3pm         29.139466
# Cloud9am         28.735905
# Pressure3pm      15.572700
# Pressure9am      15.537092
# WindGustDir      11.762611
# WindGustSpeed    11.762611
# WindDir9am        9.839763
# WindDir3pm        3.655786
# RainToday         2.848665
# Rainfall          2.848665
# RainTomorrow      2.836795
# WindSpeed3pm      1.270030
# Humidity3pm       1.210682
# Temp3pm           1.139466
# WindSpeed9am      0.902077
# MinTemp           0.890208
# MaxTemp           0.712166
# Humidity9am       0.700297
# Temp9am           0.664688
# Location          0.000000
# Date              0.000000
# dtype: float64

# %% [markdown]
# **Observations**
# 1. Column like Evaporation, Sunshine, Cloud9am, Cloud3pm are having missing values greater than the 25% may contain the important information and should be filled with appropriate statistic
# 2. for remaining values we can impute the data by mean or mode according to the dataset

# %%
#Describing the dataset
df.describe()
# Out:
#            MinTemp      MaxTemp     Rainfall  Evaporation     Sunshine  \
# count  8350.000000  8365.000000  8185.000000  4913.000000  4431.000000
# mean     13.193305    23.859976     2.805913     5.389395     7.632205
# std       5.403596     6.136408    10.459379     5.044484     3.896235
# min      -2.000000     8.200000     0.000000     0.000000     0.000000
# 25%       9.200000    19.300000     0.000000     2.600000     4.750000
# 50%      13.300000    23.300000     0.000000     4.600000     8.700000
# 75%      17.400000    28.000000     1.000000     7.000000    10.700000
# max      28.500000    45.500000   371.000000   145.000000    13.900000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count    7434.000000   8349.000000   8318.000000  8366.000000  8323.000000
# mean       40.174469     13.847646     18.533662    67.822496    51.249790
# std        14.665721     10.174579      9.766986    16.833283    18.423774
# min         7.000000      0.000000      0.000000    10.000000     6.000000
# 25%        30.000000      6.000000     11.000000    56.000000    39.000000
# 50%        39.000000     13.000000     19.000000    68.000000    51.000000
# 75%        50.000000     20.000000     24.000000    80.000000    63.000000
# max       107.000000     63.000000     83.000000   100.000000    99.000000
#
#        Pressure9am  Pressure3pm     Cloud9am     Cloud3pm      Temp9am  \
# count  7116.000000  7113.000000  6004.000000  5970.000000  8369.000000
# mean   1017.640233  1015.236075     4.566622     4.503183    17.762015
# std       6.828699     6.766681     2.877658     2.731659     5.627035
# min     989.800000   982.900000     0.000000     0.000000     1.900000
# 25%    1013.000000  1010.400000     1.000000     2.000000    13.800000
# 50%    1017.700000  1015.300000     5.000000     5.000000    17.800000
# 75%    1022.300000  1019.800000     7.000000     7.000000    21.900000
# max    1039.000000  1036.000000     8.000000     8.000000    39.400000
#
#            Temp3pm
# count  8329.000000
# mean     22.442934
# std       5.980020
# min       7.300000
# 25%      18.000000
# 50%      21.900000
# 75%      26.400000
# max      44.100000

# %% [markdown]
# **Observation**
# 1. Rainfall is highly positively skewed as the mean is very high as compared to median
# 2. Evaporation is also right skewed, as mean is greater than median
# 3. windspeed9am and windgustspeed are  positively skewed, but to be treated for removal of skewness
# 4. Sunshine is negatively skewed but is in acceptable range
# 5. other columns are near normal or in acceptable range

# %% [markdown]
# **changing date column in to year, month and day**

# %%
# Converting date to Datetime datatype
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Separating date feature to 3 attributes
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day

# %%
#Checking the skewness of the database
df.skew().sort_values(ascending=False)
# Out:
# Rainfall         13.028837
# Evaporation      10.710605
# WindSpeed9am      0.956250
# WindGustSpeed     0.711103
# WindSpeed3pm      0.491069
# Year              0.418663
# Temp3pm           0.395061
# MaxTemp           0.379297
# Humidity3pm       0.117563
# Month             0.039388
# Day               0.004260
# Pressure3pm      -0.009385
# Temp9am          -0.014699
# Pressure9am      -0.022133
# MinTemp          -0.089588
# Cloud3pm         -0.232598
# Humidity9am      -0.255843
# Cloud9am         -0.309417
# Sunshine         -0.519717
# dtype: float64

# %% [markdown]
# As discussed earlier we have found out the result of skew as predicted by the describe and have to be treated while preprocessing

# %%
# Count Plot for the Rain tomorrow
sns.countplot(x=df['RainTomorrow'])
df['RainTomorrow'].value_counts()/8425*100
# Out:
# No     73.531157
# Yes    23.632047
# Name: RainTomorrow, dtype: float64

# %% [markdown]
# As we can see only for 24% times rain came on the next day and for 78% it was not seen

# %%
# Count Plot for the Rain today
sns.countplot(x=df['RainToday'])
df['RainToday'].value_counts()/8425*100
# Out:
# No     73.531157
# Yes    23.620178
# Name: RainToday, dtype: float64

# %% [markdown]
# It is seen that the rain is following the same pattern

# %%
# Count Plot for location
sns.countplot(x=df['Location'],hue=df['RainTomorrow'])
plt.xticks(rotation=50)
df['Location'].value_counts()/8425*100
# Out:
# Melbourne       19.252226
# Williamtown     14.599407
# PerthAirport    14.290801
# Albury          10.765579
# Newcastle        9.756677
# CoffsHarbour     7.252226
# Brisbane         6.872404
# Penrith          5.721068
# Wollongong       5.626113
# Darwin           2.967359
# Adelaide         2.433234
# Uluru            0.462908
# Name: Location, dtype: float64

# %% [markdown]
# In Melbourne we can see that rain happened for more occurance

# %%
# Plotting scatterplot between minTemp and MaxTemp and raintomorrow
sns.scatterplot(data=df,x='MinTemp',y='MaxTemp',hue='RainTomorrow')
# Out:
# <AxesSubplot:xlabel='MinTemp', ylabel='MaxTemp'>

# %% [markdown]
# As temperature increases the possibility of raining decreases

# %%
# Plotting scatterplot between minTemp and MaxTemp and rainfall 
sns.scatterplot(data=df,x='MinTemp',y='MaxTemp',hue='Rainfall')
# Out:
# <AxesSubplot:xlabel='MinTemp', ylabel='MaxTemp'>

# %% [markdown]
# The amount of the rainfall is at min temp greater than 15 and max temp is less than 30

# %%
# Plotting scatterplot between windspeed9am and windspeed3pm and rainfall 
sns.scatterplot(data=df,x='WindSpeed9am',y='WindSpeed3pm',hue='Rainfall')
# Out:
# <AxesSubplot:xlabel='WindSpeed9am', ylabel='WindSpeed3pm'>

# %% [markdown]
# As we can see that the rainfall is almost same for windspeed range, except some values

# %%
# Plotting scatterplot between windspeed9am and windspeed3pm and RainTomorrow 
sns.scatterplot(data=df,x='WindSpeed9am',y='WindSpeed3pm',hue='RainTomorrow')
# Out:
# <AxesSubplot:xlabel='WindSpeed9am', ylabel='WindSpeed3pm'>

# %% [markdown]
# When windspeed at 3pm is higher it has showed rain tomorrow

# %%
# Plotting scatterplot between Humidity and RainTomorrow 
sns.scatterplot(data=df,x='Humidity9am',y='Humidity3pm',hue='RainTomorrow')
# Out:
# <AxesSubplot:xlabel='Humidity9am', ylabel='Humidity3pm'>

# %% [markdown]
# It is seen that when humidity becomes high the possibility of raining is higher

# %%
# Plotting scatterplot between humidity and Rainfall
sns.scatterplot(data=df,x='Humidity9am',y='Humidity3pm',hue='Rainfall')
# Out:
# <AxesSubplot:xlabel='Humidity9am', ylabel='Humidity3pm'>

# %% [markdown]
# Higher Humidity has resulted high amount of rainfall too in some cases

# %%
# Plotting scatterplot between pressure and Rainfall
sns.scatterplot(data=df,x='Pressure9am',y='Pressure3pm',hue='Rainfall')
# Out:
# <AxesSubplot:xlabel='Pressure9am', ylabel='Pressure3pm'>

# %% [markdown]
# As we can see that when pressure is lower side the amount of rainfall is higher

# %%
# Plotting scatterplot between pressure and RainTommorow
sns.scatterplot(data=df,x='Pressure9am',y='Pressure3pm',hue='RainTomorrow')
# Out:
# <AxesSubplot:xlabel='Pressure9am', ylabel='Pressure3pm'>

# %% [markdown]
# As we can see that the for lower pressure ranges we have higher possibility of raining tomorrow

# %%
# Plotting scatterplot between cloud condition and RainTommorow
sns.scatterplot(data=df,x='Cloud9am',y='Cloud3pm',hue='RainTomorrow')
# Out:
# <AxesSubplot:xlabel='Cloud9am', ylabel='Cloud3pm'>

# %% [markdown]
# It is very simple to guess when it is cloudy it is raining

# %%
# Plotting scatterplot between cloud condition and Rainfall
sns.scatterplot(data=df,x='Cloud9am',y='Cloud3pm',hue='Rainfall')
# Out:
# <AxesSubplot:xlabel='Cloud9am', ylabel='Cloud3pm'>

# %% [markdown]
# It is very simple to guess when it is cloudy it is raining with high amount of rainfall

# %%
# Plotting scatterplot between temperature and Rainfall
sns.scatterplot(data=df,x='Temp9am',y='Temp3pm',hue='Rainfall')
# Out:
# <AxesSubplot:xlabel='Temp9am', ylabel='Temp3pm'>

# %% [markdown]
# Amount of rainfall is depending on lower temperature

# %%
# Plotting scatterplot between temperature and RainTomorrow
sns.scatterplot(data=df,x='Temp9am',y='Temp3pm',hue='RainTomorrow')
# Out:
# <AxesSubplot:xlabel='Temp9am', ylabel='Temp3pm'>

# %% [markdown]
# when temp is on lower range it is raining

# %%
# Generating the paiplot 
for i in df.columns:
    if df[i].dtypes!='object':
        print("Histogram for ", i )
        sns.distplot(df[i])
        plt.show()
# Out:
# Histogram for  Date
# Histogram for  MinTemp
# Histogram for  MaxTemp
# Histogram for  Rainfall
# Histogram for  Evaporation
# Histogram for  Sunshine
# Histogram for  WindGustSpeed
# Histogram for  WindSpeed9am
# Histogram for  WindSpeed3pm
# Histogram for  Humidity9am
# Histogram for  Humidity3pm
# Histogram for  Pressure9am
# Histogram for  Pressure3pm
# Histogram for  Cloud9am
# Histogram for  Cloud3pm
# Histogram for  Temp9am
# Histogram for  Temp3pm
# Histogram for  Year
# Histogram for  Month
# Histogram for  Day

# %% [markdown]
# **Observation**
# 1. Rainfall is highly positively skewed as the mean is very high as compared to median
# 2. Evaporation is also right skewed, as mean is greater than median
# 3. windspeed9am and windgustspeed are  positively skewed, but to be treated for removal of skewness
# 4. Sunshine is negatively skewed but is in acceptable range
# 5. other columns are near normal or in acceptable range

# %%
# Ploting thebox plot for the dataset
df.plot(kind="box", subplots=True, layout=(4,5), figsize=(27,25),sharex=False, sharey=False)
# Out:
# MinTemp              AxesSubplot(0.125,0.71587;0.133621x0.16413)
# MaxTemp           AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# Rainfall           AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# Evaporation       AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# Sunshine          AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# WindGustSpeed       AxesSubplot(0.125,0.518913;0.133621x0.16413)
# WindSpeed9am     AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# WindSpeed3pm      AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# Humidity9am      AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# Humidity3pm      AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# Pressure9am         AxesSubplot(0.125,0.321957;0.133621x0.16413)
# Pressure3pm      AxesSubplot(0.285345,0.321957;0.133621x0.16413)
# Cloud9am          AxesSubplot(0.44569,0.321957;0.133621x0.16413)
# Cloud3pm         AxesSubplot(0.606034,0.321957;0.133621x0.16413)
# Temp9am          AxesSubplot(0.766379,0.321957;0.133621x0.16413)
# Temp3pm                AxesSubplot(0.125,0.125;0.133621x0.16413)
# Year                AxesSubplot(0.285345,0.125;0.133621x0.16413)
# Month                AxesSubplot(0.44569,0.125;0.133621x0.16413)
# Day                 AxesSubplot(0.606034,0.125;0.133621x0.16413)
# dtype: object

# %% [markdown]
# As we can see that there are multiple columns having the the outliers present in the data have to be handled in the preprocessing steps

# %% [markdown]
# **Correlation matrix**

# %%
# Finding correlation between variables
corr_mat=df.corr()
corr_mat
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.720955  0.091642     0.348643  0.081365
# MaxTemp        0.720955  1.000000 -0.088906     0.424728  0.523909
# Rainfall       0.091642 -0.088906  1.000000     0.043463 -0.209654
# Evaporation    0.348643  0.424728  0.043463     1.000000  0.340893
# Sunshine       0.081365  0.523909 -0.209654     0.340893  1.000000
# WindGustSpeed  0.241317  0.146113  0.104999     0.214069 -0.018455
# WindSpeed9am   0.137263  0.013425  0.051349     0.176701 -0.025112
# WindSpeed3pm   0.180091  0.088797  0.025185     0.142421  0.045031
# Humidity9am   -0.130906 -0.392496  0.231702    -0.286869 -0.512349
# Humidity3pm    0.079569 -0.424217  0.238730    -0.221244 -0.630536
# Pressure9am   -0.465478 -0.347285 -0.080412    -0.218171  0.028666
# Pressure3pm   -0.458665 -0.430074 -0.037270    -0.233401 -0.047098
# Cloud9am       0.111213 -0.307700  0.195157    -0.084288 -0.705577
# Cloud3pm       0.046889 -0.301675  0.159250    -0.152637 -0.723957
# Temp9am        0.888342  0.869503 -0.007191     0.405467  0.348708
# Temp3pm        0.689652  0.978665 -0.092263     0.414156  0.546057
# Year           0.044324  0.120234  0.006530     0.256852  0.144615
# Month         -0.247142 -0.163891 -0.012522     0.005729 -0.009156
# Day            0.009494  0.015668 -0.013953     0.017785  0.006420
#
#                WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# MinTemp             0.241317      0.137263      0.180091    -0.130906
# MaxTemp             0.146113      0.013425      0.088797    -0.392496
# Rainfall            0.104999      0.051349      0.025185     0.231702
# Evaporation         0.214069      0.176701      0.142421    -0.286869
# Sunshine           -0.018455     -0.025112      0.045031    -0.512349
# WindGustSpeed       1.000000      0.656079      0.711403    -0.286045
# WindSpeed9am        0.656079      1.000000      0.566322    -0.358981
# WindSpeed3pm        0.711403      0.566322      1.000000    -0.252488
# Humidity9am        -0.286045     -0.358981     -0.252488     1.000000
# Humidity3pm        -0.097380     -0.111595     -0.091248     0.636255
# Pressure9am        -0.430736     -0.197189     -0.291271     0.154699
# Pressure3pm        -0.394745     -0.156517     -0.240378     0.188463
# Cloud9am            0.030124     -0.000607      0.005807     0.472126
# Cloud3pm            0.104157      0.068930      0.003894     0.352736
# Temp9am             0.211477      0.109936      0.185329    -0.378389
# Temp3pm             0.106872     -0.002619      0.066201    -0.383788
# Year               -0.045032     -0.089133     -0.051882     0.100085
# Month               0.055158      0.038668      0.049760    -0.116017
# Day                -0.003062     -0.003081     -0.009017     0.003814
#
#                Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# MinTemp           0.079569    -0.465478    -0.458665  0.111213  0.046889
# MaxTemp          -0.424217    -0.347285    -0.430074 -0.307700 -0.301675
# Rainfall          0.238730    -0.080412    -0.037270  0.195157  0.159250
# Evaporation      -0.221244    -0.218171    -0.233401 -0.084288 -0.152637
# Sunshine         -0.630536     0.028666    -0.047098 -0.705577 -0.723957
# WindGustSpeed    -0.097380    -0.430736    -0.394745  0.030124  0.104157
# WindSpeed9am     -0.111595    -0.197189    -0.156517 -0.000607  0.068930
# WindSpeed3pm     -0.091248    -0.291271    -0.240378  0.005807  0.003894
# Humidity9am       0.636255     0.154699     0.188463  0.472126  0.352736
# Humidity3pm       1.000000     0.001763     0.076002  0.509797  0.520221
# Pressure9am       0.001763     1.000000     0.961922 -0.091391 -0.104535
# Pressure3pm       0.076002     0.961922     1.000000 -0.015692 -0.035986
# Cloud9am          0.509797    -0.091391    -0.015692  1.000000  0.619202
# Cloud3pm          0.520221    -0.104535    -0.035986  0.619202  1.000000
# Temp9am          -0.130973    -0.441901    -0.472788 -0.161867 -0.151438
# Temp3pm          -0.491634    -0.302488    -0.394852 -0.326547 -0.348986
# Year             -0.029118     0.033118     0.015175  0.008702 -0.013873
# Month            -0.074601     0.007693     0.002230 -0.015120  0.002811
# Day               0.012590    -0.017392    -0.012727 -0.009568  0.000787
#
#                 Temp9am   Temp3pm      Year     Month       Day
# MinTemp        0.888342  0.689652  0.044324 -0.247142  0.009494
# MaxTemp        0.869503  0.978665  0.120234 -0.163891  0.015668
# Rainfall      -0.007191 -0.092263  0.006530 -0.012522 -0.013953
# Evaporation    0.405467  0.414156  0.256852  0.005729  0.017785
# Sunshine       0.348708  0.546057  0.144615 -0.009156  0.006420
# WindGustSpeed  0.211477  0.106872 -0.045032  0.055158 -0.003062
# WindSpeed9am   0.109936 -0.002619 -0.089133  0.038668 -0.003081
# WindSpeed3pm   0.185329  0.066201 -0.051882  0.049760 -0.009017
# Humidity9am   -0.378389 -0.383788  0.100085 -0.116017  0.003814
# Humidity3pm   -0.130973 -0.491634 -0.029118 -0.074601  0.012590
# Pressure9am   -0.441901 -0.302488  0.033118  0.007693 -0.017392
# Pressure3pm   -0.472788 -0.394852  0.015175  0.002230 -0.012727
# Cloud9am      -0.161867 -0.326547  0.008702 -0.015120 -0.009568
# Cloud3pm      -0.151438 -0.348986 -0.013873  0.002811  0.000787
# Temp9am        1.000000  0.837552  0.089047 -0.165900  0.011021
# Temp3pm        0.837552  1.000000  0.133379 -0.176996  0.013028
# Year           0.089047  0.133379  1.000000 -0.090394 -0.003836
# Month         -0.165900 -0.176996 -0.090394  1.000000  0.004386
# Day            0.011021  0.013028 -0.003836  0.004386  1.000000

# %%
# Heat map for correlation matrix
plt.figure(figsize=(15,8))
sns.heatmap(corr_mat,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **observation**
# 1. MinTemp and MaxTemp variables are highly positively correlated (correlation coefficient = 0.72).
# 2. MinTemp and Temp3pm variables are also highly positively correlated (correlation coefficient = 0.69).
# 3. MinTemp and Temp9am variables are strongly positively correlated (correlation coefficient = 0.89).
# 4. MaxTemp and Temp9am variables are strongly positively correlated (correlation coefficient = 0.87).
# 5. MaxTemp and Temp3pm variables are also strongly positively correlated (correlation coefficient = 0.98).
# 6. WindGustSpeed and WindSpeed3pm variables are highly positively correlated (correlation coefficient = 0.66).
# 7. Pressure9am and Pressure3pm variables are strongly positively correlated (correlation coefficient = 0.96).
# 8. Temp9am and Temp3pm variables are strongly positively correlated (correlation coefficient = 0.84)
#
# **As we can see that there is very high multicollinearity present in the data so removing these from the dataset Temp9am', 'Temp3pm', 'Pressure3pm'** as  this would be irrelevant

# %%
# Dropping the Columns having Highest Nulvalues as discussed and dropping date and location
df=df.drop(['Date','Temp9am', 'Temp3pm', 'Pressure3pm'],axis=1)

# %% [markdown]
# **Filling the null values**

# %%
# Filling nul values
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=df[i].fillna(df[i].mode()[0])
    else:
        df[i]=df[i].fillna(df[i].median())

# %%
# Crosschecking whether null values are filled or not
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# **Encoding the dataset**

# %%
# Encoding the dataset for categorical columns
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=le.fit_transform(df[i])
df
# Out:
#       Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0            1     13.4     22.9       0.6          4.6       8.7
# 1            1      7.4     25.1       0.0          4.6       8.7
# 2            1     12.9     25.7       0.0          4.6       8.7
# 3            1      9.2     28.0       0.0          4.6       8.7
# 4            1     17.5     32.3       1.0          4.6       8.7
# ...        ...      ...      ...       ...          ...       ...
# 8420         9      2.8     23.4       0.0          4.6       8.7
# 8421         9      3.6     25.3       0.0          4.6       8.7
# 8422         9      5.4     26.9       0.0          4.6       8.7
# 8423         9      7.8     27.0       0.0          4.6       8.7
# 8424         9     14.9     23.3       0.0          4.6       8.7
#
#       WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# 0              13           44.0          13          14          20.0
# 1              14           44.0           6          15           4.0
# 2              15           46.0          13          15          19.0
# 3               4           24.0           9           0          11.0
# 4              13           41.0           1           7           7.0
# ...           ...            ...         ...         ...           ...
# 8420            0           31.0           9           1          13.0
# 8421            6           22.0           9           3          13.0
# 8422            3           37.0           9          14           9.0
# 8423            9           28.0          10           3          13.0
# 8424            3           39.0           2           2          17.0
#
#       WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Cloud9am  Cloud3pm  \
# 0             24.0         71.0         22.0       1007.7       8.0       5.0
# 1             22.0         44.0         25.0       1010.6       5.0       5.0
# 2             26.0         38.0         30.0       1007.6       5.0       2.0
# 3              9.0         45.0         16.0       1017.6       5.0       5.0
# 4             20.0         82.0         33.0       1010.8       7.0       8.0
# ...            ...          ...          ...          ...       ...       ...
# 8420          11.0         51.0         24.0       1024.6       5.0       5.0
# 8421           9.0         56.0         21.0       1023.5       5.0       5.0
# 8422           9.0         53.0         24.0       1021.0       5.0       5.0
# 8423           7.0         51.0         24.0       1019.4       3.0       2.0
# 8424          17.0         62.0         36.0       1020.2       8.0       8.0
#
#       RainToday  RainTomorrow  Year  Month  Day
# 0             0             0  2008     12    1
# 1             0             0  2008     12    2
# 2             0             0  2008     12    3
# 3             0             0  2008     12    4
# 4             0             0  2008     12    5
# ...         ...           ...   ...    ...  ...
# 8420          0             0  2017      6   21
# 8421          0             0  2017      6   22
# 8422          0             0  2017      6   23
# 8423          0             0  2017      6   24
# 8424          0             0  2017      6   25
#
# [8425 rows x 22 columns]

# %%
# encoding the year column
df['Year']=le.fit_transform(df['Year'])

# %% [markdown]
# **Removing Outliers**

# %%
# Importing Zscore
from scipy.stats import zscore
z=np.abs(zscore(df))
z.shape
# Out:
# (8425, 22)

# %%
# Setting threshold at 3 and detecting the outliers
threshold=3
print(np.where(z>3))
# Out:
# (array([  12,   44,   52,   52,   60,   61,   62,   62,   67,   68,  123,
#         267,  296,  381,  381,  405,  406,  407,  431,  462,  563,  568,
#         569,  683,  699,  713,  748,  770,  796,  797,  802,  928,  935,
#         949,  979,  980,  980,  980, 1008, 1009, 1011, 1138, 1148, 1149,
#        1151, 1189, 1202, 1203, 1237, 1241, 1264, 1265, 1357, 1411, 1412,
#        1413, 1479, 1480, 1481, 1513, 1535, 1587, 1644, 1661, 1665, 1673,
#        1680, 1774, 1819, 1873, 1898, 1903, 1945, 2016, 2028, 2043, 2063,
#        2074, 2108, 2116, 2186, 2201, 2219, 2219, 2230, 2231, 2265, 2429,
#        2488, 2500, 2505, 2527, 2541, 2593, 2676, 2677, 2735, 2827, 2835,
#        2849, 2849, 2855, 2863, 2869, 2877, 2883, 2890, 2891, 2897, 2898,
#        2900, 2901, 2905, 2909, 2911, 2919, 2925, 2933, 2939, 2947, 2953,
#        2961, 2967, 2975, 2989, 3003, 3051, 3059, 3060, 3066, 3067, 3067,
#        3067, 3068, 3070, 3082, 3082, 3082, 3089, 3089, 3099, 3099, 3101,
#        3141, 3150, 3153, 3157, 3164, 3172, 3172, 3178, 3185, 3206, 3212,
#        3213, 3221, 3227, 3234, 3248, 3248, 3260, 3278, 3291, 3302, 3350,
#        3419, 3421, 3430, 3449, 3449, 3449, 3450, 3450, 3458, 3471, 3491,
#        3557, 3571, 3602, 3603, 3607, 3617, 3621, 3679, 3687, 3701, 3701,
#        3707, 3715, 3721, 3729, 3735, 3742, 3743, 3749, 3750, 3752, 3753,
#        3757, 3761, 3763, 3771, 3777, 3785, 3791, 3799, 3805, 3813, 3819,
#        3827, 3841, 3855, 3903, 3911, 3912, 3918, 3919, 3919, 3919, 3920,
#        3922, 3934, 3934, 3934, 3941, 3941, 3951, 3951, 3953, 3993, 4002,
#        4005, 4009, 4016, 4024, 4024, 4030, 4037, 4058, 4064, 4065, 4073,
#        4079, 4086, 4100, 4100, 4112, 4130, 4143, 4154, 4202, 4271, 4273,
#        4282, 4301, 4301, 4301, 4302, 4302, 4310, 4323, 4343, 4409, 4423,
#        4454, 4455, 4459, 4469, 4473, 4528, 4535, 4566, 4568, 4568, 4618,
#        4619, 4638, 4650, 4657, 4672, 4673, 4678, 4731, 4775, 4780, 4798,
#        4833, 4833, 4837, 4843, 4854, 4854, 4855, 4859, 4886, 4892, 4895,
#        4911, 4918, 4934, 4956, 4960, 4979, 5010, 5038, 5122, 5123, 5138,
#        5155, 5176, 5179, 5188, 5188, 5201, 5202, 5204, 5204, 5207, 5207,
#        5211, 5212, 5212, 5213, 5214, 5214, 5235, 5243, 5252, 5264, 5274,
#        5275, 5288, 5301, 5307, 5314, 5318, 5323, 5324, 5324, 5339, 5346,
#        5377, 5379, 5379, 5429, 5430, 5449, 5461, 5468, 5483, 5484, 5489,
#        5542, 5586, 5591, 5609, 5644, 5644, 5648, 5654, 5665, 5665, 5666,
#        5670, 5697, 5703, 5706, 5722, 5729, 5745, 5767, 5771, 5790, 5821,
#        5849, 5933, 5934, 5949, 5966, 5987, 5990, 5999, 5999, 6012, 6013,
#        6015, 6015, 6018, 6018, 6022, 6023, 6023, 6024, 6025, 6025, 6046,
#        6054, 6063, 6075, 6085, 6086, 6099, 6112, 6118, 6125, 6129, 6134,
#        6135, 6135, 6149, 6182, 6441, 6480, 6481, 6489, 6520, 6583, 6584,
#        6786, 6794, 6848, 6848, 6849, 6860, 6862, 6863, 6876, 6880, 6883,
#        6886, 6903, 6904, 6918, 6925, 6930, 6933, 6934, 6960, 6960, 6978,
#        7111, 7162, 7169, 7186, 7187, 7188, 7282, 7303, 7366, 7402, 7462,
#        7462, 7565, 7575, 7602, 7633, 7633, 7735, 7827, 7857, 7872, 7983,
#        7984, 7984, 8100, 8136, 8144, 8145, 8145, 8185], dtype=int64), array([14,  2,  7, 11,  2,  2,  2,  7,  2,  2,  7,  7, 14,  7, 11,  2,  2,
#         2,  3,  3,  7, 14, 14, 14,  3,  3, 14,  3,  3,  3,  3,  3,  3,  3,
#         3,  3,  7, 10,  3,  3,  3,  3,  3,  3,  3, 11,  3,  3,  3,  3,  3,
#         3,  3,  3,  3,  3,  3,  3,  3,  3, 10, 11, 11,  3, 11,  3,  3,  3,
#         3,  3, 11, 10, 10, 10, 11, 11,  3, 10,  3,  3, 10,  3, 10, 11, 11,
#         3,  3,  3,  3,  7,  7,  2,  3,  3,  3,  3,  3,  4,  4,  3,  4,  4,
#         4,  4,  4,  4,  3,  4,  4,  3,  3,  3,  4,  3,  4,  4,  4,  4,  4,
#         4,  4,  4,  4,  4,  4,  3,  3, 14, 14,  7,  7, 10, 11, 10,  7,  7,
#        10, 11,  7, 10,  7, 11,  4, 11,  4, 11,  4,  4,  4, 11,  4,  4,  4,
#        11,  4,  4,  4,  7,  3,  4,  4,  2,  2,  2,  3,  3,  3,  3,  3,  7,
#        14,  7, 14, 11, 11,  7, 10,  3,  7,  7,  3, 11,  3,  4,  4,  3,  4,
#         4,  4,  4,  4,  4,  3,  4,  4,  3,  3,  3,  4,  3,  4,  4,  4,  4,
#         4,  4,  4,  4,  4,  4,  4,  3,  3, 14, 14,  7,  7, 10, 11, 10,  7,
#         7, 10, 11,  7, 10,  7, 11,  4, 11,  4, 11,  4,  4,  4, 11,  4,  4,
#         4, 11,  4,  4,  4,  7,  3,  4,  4,  2,  2,  2,  3,  3,  3,  3,  3,
#         7, 14,  7, 14, 11, 11,  7, 10,  3,  7,  7,  3, 11,  3, 14, 10,  7,
#         3, 14,  2,  4, 10,  3, 10,  7,  3, 14, 10,  7, 14, 11,  7, 10,  7,
#        11, 11, 14,  7, 10, 11, 10, 14,  3, 10, 10, 10, 14, 10,  3, 10, 14,
#        14, 14, 10, 14, 10,  7, 10, 10, 11,  7, 10, 10, 11, 10, 10, 11, 10,
#         3, 14, 10, 10, 10,  7,  3, 10,  3,  7, 10, 10, 10, 10,  4, 10, 14,
#        10,  7,  3, 14,  2,  4, 10,  3, 10,  7,  3, 14, 10,  7, 14, 11,  7,
#        10,  7, 11, 11, 14,  7, 10, 11, 10, 14,  3, 10, 10, 10, 14, 10,  3,
#        10, 14, 14, 14, 10, 14, 10,  7, 10, 10, 11,  7, 10, 10, 11, 10, 10,
#        11, 10,  3, 14, 10, 10, 10,  7,  3, 10,  3,  7, 10, 10, 10, 10,  4,
#        10,  3,  3,  3,  3,  3,  3,  3,  3,  3, 14, 14,  7, 12,  4, 12,  4,
#        12,  4, 12,  4, 12, 12,  4,  4,  4,  4, 12, 12,  4,  7, 14,  3, 11,
#         3, 14, 14, 14,  3,  7, 12, 12,  7, 14,  7, 12, 12,  7, 11, 14,  3,
#         3,  7,  2,  2, 12,  3,  3,  3,  3,  7,  3], dtype=int64))

# %%
# Removing the outlier 
df1=df[(z<3).all(axis=1)]
df1.shape
# Out:
# (8009, 22)

# %%
# Data Loss
loss=(8425-8009)/8009*100
loss
# Out:
# 5.194156573854414

# %% [markdown]
# **We can see that only 5.19% data loss is there we can proceed further by removing the outliers from the dataset**

# %%
#assigning the dataset
df=df1

# %% [markdown]
# # Regression Model for predicting rainfall in mm

# %%
# Copying database for the regression model 
dfr=df.copy()
dfr
# Out:
#       Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0            1     13.4     22.9       0.6          4.6       8.7
# 1            1      7.4     25.1       0.0          4.6       8.7
# 2            1     12.9     25.7       0.0          4.6       8.7
# 3            1      9.2     28.0       0.0          4.6       8.7
# 4            1     17.5     32.3       1.0          4.6       8.7
# ...        ...      ...      ...       ...          ...       ...
# 8420         9      2.8     23.4       0.0          4.6       8.7
# 8421         9      3.6     25.3       0.0          4.6       8.7
# 8422         9      5.4     26.9       0.0          4.6       8.7
# 8423         9      7.8     27.0       0.0          4.6       8.7
# 8424         9     14.9     23.3       0.0          4.6       8.7
#
#       WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# 0              13           44.0          13          14          20.0
# 1              14           44.0           6          15           4.0
# 2              15           46.0          13          15          19.0
# 3               4           24.0           9           0          11.0
# 4              13           41.0           1           7           7.0
# ...           ...            ...         ...         ...           ...
# 8420            0           31.0           9           1          13.0
# 8421            6           22.0           9           3          13.0
# 8422            3           37.0           9          14           9.0
# 8423            9           28.0          10           3          13.0
# 8424            3           39.0           2           2          17.0
#
#       WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Cloud9am  Cloud3pm  \
# 0             24.0         71.0         22.0       1007.7       8.0       5.0
# 1             22.0         44.0         25.0       1010.6       5.0       5.0
# 2             26.0         38.0         30.0       1007.6       5.0       2.0
# 3              9.0         45.0         16.0       1017.6       5.0       5.0
# 4             20.0         82.0         33.0       1010.8       7.0       8.0
# ...            ...          ...          ...          ...       ...       ...
# 8420          11.0         51.0         24.0       1024.6       5.0       5.0
# 8421           9.0         56.0         21.0       1023.5       5.0       5.0
# 8422           9.0         53.0         24.0       1021.0       5.0       5.0
# 8423           7.0         51.0         24.0       1019.4       3.0       2.0
# 8424          17.0         62.0         36.0       1020.2       8.0       8.0
#
#       RainToday  RainTomorrow  Year  Month  Day
# 0             0             0     0     12    1
# 1             0             0     0     12    2
# 2             0             0     0     12    3
# 3             0             0     0     12    4
# 4             0             0     0     12    5
# ...         ...           ...   ...    ...  ...
# 8420          0             0     9      6   21
# 8421          0             0     9      6   22
# 8422          0             0     9      6   23
# 8423          0             0     9      6   24
# 8424          0             0     9      6   25
#
# [8009 rows x 22 columns]

# %%
# Checking the skewness
dfr.skew()
# Out:
# Location        -0.042269
# MinTemp         -0.080542
# MaxTemp          0.328885
# Rainfall         3.524715
# Evaporation      1.286271
# Sunshine        -1.212459
# WindGustDir      0.111576
# WindGustSpeed    0.542684
# WindDir9am       0.162915
# WindDir3pm      -0.127700
# WindSpeed9am     0.712131
# WindSpeed3pm     0.299740
# Humidity9am     -0.230962
# Humidity3pm      0.122029
# Pressure9am      0.026995
# Cloud9am        -0.504789
# Cloud3pm        -0.445595
# RainToday        1.303717
# RainTomorrow     1.295247
# Year             0.429323
# Month            0.053975
# Day              0.001580
# dtype: float64

# %% [markdown]
# As we can see that only one columns is there to remove skewness is WindSpeed9am

# %%
# Removing skewness from dataset
#dfr['WindSpeed9am'] = np.log(dfr['WindSpeed9am'])
#dfr.skew()

# %% [markdown]
# **As we cansee that the skewness is being removed and all the data is in acceptable range**
# Note: Skewness from the rainfall column is not removed as this is a target variable and raintoday and rain tomorrow are categorical variable and not be treated for skewness

# %% [markdown]
# **Splittingthe data in Inputs and target variable**

# %%
#Splitting the datbase into inputs and output
x=dfr.drop(['Rainfall'],axis=1)
y=dfr['Rainfall']
print(x.shape)
print(y.shape)
# Out:
# (8009, 21)
# (8009,)

# %%
#importing the StandardScaler
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)
x
# Out:
# array([[-1.50889904,  0.05584869, -0.14584649, ..., -1.66161235,
#          1.63483858, -1.67315903],
#        [-1.50889904, -1.0570029 ,  0.21914882, ..., -1.66161235,
#          1.63483858, -1.55945526],
#        [-1.50889904, -0.03688894,  0.31869299, ..., -1.66161235,
#          1.63483858, -1.44575149],
#        ...,
#        [ 1.02785358, -1.42795343,  0.51778134, ...,  2.00098756,
#         -0.12321838,  0.82832396],
#        [ 1.02785358, -0.98281279,  0.53437204, ...,  2.00098756,
#         -0.12321838,  0.94202773],
#        [ 1.02785358,  0.33406159, -0.07948371, ...,  2.00098756,
#         -0.12321838,  1.05573151]])

# %%
# importing Linear Regression and metrics for it
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split

# %%
# Finding the best Random State
maxr2=0
maxrs=0
lr=LinearRegression()
for i in range(0,200):
    print("Random State is ", i)
    xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.20,random_state=i)
    lr.fit(xtrain,ytrain)
    predtrain=lr.predict(xtrain)
    predtest=lr.predict(xtest)
    print('training accuracy is ', r2_score(ytrain,predtrain))
    score=r2_score(ytest,predtest)
    print('testing accuracy is ', score)
    print("\n")
    
    if score>maxr2:
        maxr2=score
        maxrs=i
        
        
print("maximum r2 score is ", maxr2 , "at random state ", maxrs)
# Out:
# Random State is  0
# training accuracy is  0.49452952453052945
# testing accuracy is  0.5087658885187064
#
#
# Random State is  1
# training accuracy is  0.5011948012357004
# testing accuracy is  0.4808577538149479
#
#
# Random State is  2
# training accuracy is  0.4936398322098233
# testing accuracy is  0.511228626225829
#
#
# Random State is  3
# training accuracy is  0.4927096940346811
# testing accuracy is  0.5147349785751714
#
#
# Random State is  4
# training accuracy is  0.5013663781921534
# testing accuracy is  0.47799423044509093
#
#
# Random State is  5
# training accuracy is  0.5025163473744858
# testing accuracy is  0.4763401200021208
#
#
# Random State is  6
# training accuracy is  0.49694919947280414
# testing accuracy is  0.49692660378076214
#
#
# Random State is  7
# training accuracy is  0.4977080520836764
# testing accuracy is  0.4934736449364012
#
#
# Random State is  8
# training accuracy is  0.49809149358263805
# testing accuracy is  0.49158871500251866
#
#
# Random State is  9
# training accuracy is  0.4944861343759366
# testing accuracy is  0.5055246702246468
#
#
# Random State is  10
# training accuracy is  0.497010799351165
# testing accuracy is  0.49766208989977667
#
#
# Random State is  11
# training accuracy is  0.49608864356471505
# testing accuracy is  0.49948852446680414
#
#
# Random State is  12
# training accuracy is  0.4949739419117447
# testing accuracy is  0.5063742779022272
#
#
# Random State is  13
# training accuracy is  0.49567762883569266
# testing accuracy is  0.5031686262199554
#
#
# Random State is  14
# training accuracy is  0.49817366265262086
# testing accuracy is  0.4928678693459334
#
#
# Random State is  15
# training accuracy is  0.49597244368138305
# testing accuracy is  0.5006640301570019
#
#
# Random State is  16
# training accuracy is  0.4940234543477162
# testing accuracy is  0.5084915689741245
#
#
# Random State is  17
# training accuracy is  0.503490769439364
# testing accuracy is  0.4688254588142463
#
#
# Random State is  18
# training accuracy is  0.4967217904687756
# testing accuracy is  0.49769019126495284
#
#
# Random State is  19
# training accuracy is  0.5008466187279672
# testing accuracy is  0.4815779061949068
#
#
# Random State is  20
# training accuracy is  0.4937836828282919
# testing accuracy is  0.5101637562592554
#
#
# Random State is  21
# training accuracy is  0.4933934691439861
# testing accuracy is  0.5115761386316835
#
#
# Random State is  22
# training accuracy is  0.49551322568620537
# testing accuracy is  0.5024667697723504
#
#
# Random State is  23
# training accuracy is  0.5035820401988487
# testing accuracy is  0.46967627023150627
#
#
# Random State is  24
# training accuracy is  0.49153534883491845
# testing accuracy is  0.5217746868780959
#
#
# Random State is  25
# training accuracy is  0.49922116593758237
# testing accuracy is  0.48838124637751257
#
#
# Random State is  26
# training accuracy is  0.5014857538043775
# testing accuracy is  0.48153781937902573
#
#
# Random State is  27
# training accuracy is  0.4954629677921357
# testing accuracy is  0.5035782883798681
#
#
# Random State is  28
# training accuracy is  0.4930580839424552
# testing accuracy is  0.513704573470654
#
#
# Random State is  29
# training accuracy is  0.4973410863623432
# testing accuracy is  0.4951498265246548
#
#
# Random State is  30
# training accuracy is  0.4922337058500055
# testing accuracy is  0.5195632553533516
#
#
# Random State is  31
# training accuracy is  0.4954691062353541
# testing accuracy is  0.5027745663844553
#
#
# Random State is  32
# training accuracy is  0.4968505335086594
# testing accuracy is  0.4972268465295344
#
#
# Random State is  33
# training accuracy is  0.48939627869299795
# testing accuracy is  0.5276649349319017
#
#
# Random State is  34
# training accuracy is  0.49462653546546964
# testing accuracy is  0.5059075441520716
#
#
# Random State is  35
# training accuracy is  0.496573474495408
# testing accuracy is  0.49871159820645405
#
#
# Random State is  36
# training accuracy is  0.500091010381773
# testing accuracy is  0.48338527882667726
#
#
# Random State is  37
# training accuracy is  0.5016062434063464
# testing accuracy is  0.4699354880264731
#
#
# Random State is  38
# training accuracy is  0.4967091778542809
# testing accuracy is  0.4988764543466804
#
#
# Random State is  39
# training accuracy is  0.4943437808923512
# testing accuracy is  0.5090288212954474
#
#
# Random State is  40
# training accuracy is  0.4983990080586065
# testing accuracy is  0.49153580811706443
#
#
# Random State is  41
# training accuracy is  0.5039233992189135
# testing accuracy is  0.46655531549656026
#
#
# Random State is  42
# training accuracy is  0.5005218292658216
# testing accuracy is  0.47445083499085283
#
#
# Random State is  43
# training accuracy is  0.49280508017177516
# testing accuracy is  0.5118201309214228
#
#
# Random State is  44
# training accuracy is  0.4959540416862509
# testing accuracy is  0.5012160435675121
#
#
# Random State is  45
# training accuracy is  0.49492457503126175
# testing accuracy is  0.5040955744636033
#
#
# Random State is  46
# training accuracy is  0.495757770983982
# testing accuracy is  0.5012344995167209
#
#
# Random State is  47
# training accuracy is  0.4930511217039787
# testing accuracy is  0.514213097678274
#
#
# Random State is  48
# training accuracy is  0.5031511879952786
# testing accuracy is  0.47422915383869135
#
#
# Random State is  49
# training accuracy is  0.49031432351020365
# testing accuracy is  0.5275131141705622
#
#
# Random State is  50
# training accuracy is  0.4950914288026276
# testing accuracy is  0.5039797952136865
#
#
# Random State is  51
# training accuracy is  0.5049611203548612
# testing accuracy is  0.4653831388302535
#
#
# Random State is  52
# training accuracy is  0.5019532723628841
# testing accuracy is  0.47952688499668505
#
#
# Random State is  53
# training accuracy is  0.49312655657025717
# testing accuracy is  0.5133088112579742
#
#
# Random State is  54
# training accuracy is  0.5009224726264457
# testing accuracy is  0.48254264438463157
#
#
# Random State is  55
# training accuracy is  0.49523494505513366
# testing accuracy is  0.5043474522804104
#
#
# Random State is  56
# training accuracy is  0.5012750471204198
# testing accuracy is  0.47971648580866644
#
#
# Random State is  57
# training accuracy is  0.5038899004771724
# testing accuracy is  0.46585156984131304
#
#
# Random State is  58
# training accuracy is  0.4977756301994596
# testing accuracy is  0.492859713561174
#
#
# Random State is  59
# training accuracy is  0.4954826196359138
# testing accuracy is  0.5039658575895962
#
#
# Random State is  60
# training accuracy is  0.49571267493073223
# testing accuracy is  0.5016507424821823
#
#
# Random State is  61
# training accuracy is  0.49417615373422796
# testing accuracy is  0.5089453738536416
#
#
# Random State is  62
# training accuracy is  0.493646717654582
# testing accuracy is  0.5119214628503564
#
#
# Random State is  63
# training accuracy is  0.4945576415719748
# testing accuracy is  0.5062200466289453
#
#
# Random State is  64
# training accuracy is  0.4967010194021598
# testing accuracy is  0.49923583267163474
#
#
# Random State is  65
# training accuracy is  0.4944041748105362
# testing accuracy is  0.5075808985276968
#
#
# Random State is  66
# training accuracy is  0.49948104935646565
# testing accuracy is  0.48565041799052255
#
#
# Random State is  67
# training accuracy is  0.4951150458341397
# testing accuracy is  0.5054789147984075
#
#
# Random State is  68
# training accuracy is  0.5044866805629236
# testing accuracy is  0.47063565783310135
#
#
# Random State is  69
# training accuracy is  0.4983482983537423
# testing accuracy is  0.49235368593485085
#
#
# Random State is  70
# training accuracy is  0.5049252473294592
# testing accuracy is  0.46167753437196346
#
#
# Random State is  71
# training accuracy is  0.49402759591586687
# testing accuracy is  0.5071552601229574
#
#
# Random State is  72
# training accuracy is  0.4982567105165171
# testing accuracy is  0.4909178253607903
#
#
# Random State is  73
# training accuracy is  0.49815997618166996
# testing accuracy is  0.4930969175178751
#
#
# Random State is  74
# training accuracy is  0.49468112228929684
# testing accuracy is  0.5063710641422136
#
#
# Random State is  75
# training accuracy is  0.49154773846335276
# testing accuracy is  0.5116979701848516
#
#
# Random State is  76
# training accuracy is  0.4960549296316181
# testing accuracy is  0.5008243244675465
#
#
# Random State is  77
# training accuracy is  0.4973800264701308
# testing accuracy is  0.49414921289180624
#
#
# Random State is  78
# training accuracy is  0.4923615543927158
# testing accuracy is  0.5139936005718573
#
#
# Random State is  79
# training accuracy is  0.5003647055942066
# testing accuracy is  0.48161250320039806
#
#
# Random State is  80
# training accuracy is  0.5053367092428331
# testing accuracy is  0.46505765479536465
#
#
# Random State is  81
# training accuracy is  0.4928206667145839
# testing accuracy is  0.5102166244712274
#
#
# Random State is  82
# training accuracy is  0.5001186784461942
# testing accuracy is  0.4821050090666108
#
#
# Random State is  83
# training accuracy is  0.5024278613994859
# testing accuracy is  0.4728403556625438
#
#
# Random State is  84
# training accuracy is  0.5019530680282316
# testing accuracy is  0.48020809124899133
#
#
# Random State is  85
# training accuracy is  0.5020798547908688
# testing accuracy is  0.4768425227752111
#
#
# Random State is  86
# training accuracy is  0.499886107554241
# testing accuracy is  0.4853890535141503
#
#
# Random State is  87
# training accuracy is  0.5019422481383993
# testing accuracy is  0.4750325176350757
#
#
# Random State is  88
# training accuracy is  0.5001028963578696
# testing accuracy is  0.4845819433544697
#
#
# Random State is  89
# training accuracy is  0.49691327943879093
# testing accuracy is  0.4977919626531446
#
#
# Random State is  90
# training accuracy is  0.492233885850747
# testing accuracy is  0.5131316485803694
#
#
# Random State is  91
# training accuracy is  0.496784375704741
# testing accuracy is  0.49774486686429786
#
#
# Random State is  92
# training accuracy is  0.4996612729302665
# testing accuracy is  0.4864733337880489
#
#
# Random State is  93
# training accuracy is  0.4962426443306034
# testing accuracy is  0.4982482329354917
#
#
# Random State is  94
# training accuracy is  0.5006792449213024
# testing accuracy is  0.48157178700643133
#
#
# Random State is  95
# training accuracy is  0.49874512368799506
# testing accuracy is  0.4897977136925723
#
#
# Random State is  96
# training accuracy is  0.5003328185906613
# testing accuracy is  0.48355461347287154
#
#
# Random State is  97
# training accuracy is  0.49292944693399676
# testing accuracy is  0.5149686731165714
#
#
# Random State is  98
# training accuracy is  0.49478561976010116
# testing accuracy is  0.5058480398287736
#
#
# Random State is  99
# training accuracy is  0.49517553487779353
# testing accuracy is  0.5055672381781939
#
#
# Random State is  100
# training accuracy is  0.5011221414575405
# testing accuracy is  0.4805449364718173
#
#
# Random State is  101
# training accuracy is  0.5056980363909176
# testing accuracy is  0.4667282748383038
#
#
# Random State is  102
# training accuracy is  0.49659805225112363
# testing accuracy is  0.4982864335924684
#
#
# Random State is  103
# training accuracy is  0.4999307394013357
# testing accuracy is  0.48407392474335453
#
#
# Random State is  104
# training accuracy is  0.49565107908310757
# testing accuracy is  0.5021485106601846
#
#
# Random State is  105
# training accuracy is  0.4956921143239654
# testing accuracy is  0.5030862974081862
#
#
# Random State is  106
# training accuracy is  0.49553984030735265
# testing accuracy is  0.5015170537767712
#
#
# Random State is  107
# training accuracy is  0.5006570624705176
# testing accuracy is  0.478530782560053
#
#
# Random State is  108
# training accuracy is  0.49874186461088654
# testing accuracy is  0.49039389986614945
#
#
# Random State is  109
# training accuracy is  0.499880236169312
# testing accuracy is  0.48268252973597503
#
#
# Random State is  110
# training accuracy is  0.4920307440959254
# testing accuracy is  0.5164627326814364
#
#
# Random State is  111
# training accuracy is  0.49570270788550874
# testing accuracy is  0.5030054146355016
#
#
# Random State is  112
# training accuracy is  0.4962689253956012
# testing accuracy is  0.5010708928770315
#
#
# Random State is  113
# training accuracy is  0.49753930295260407
# testing accuracy is  0.49418605079413236
#
#
# Random State is  114
# training accuracy is  0.49756983582948366
# testing accuracy is  0.49545400064453793
#
#
# Random State is  115
# training accuracy is  0.49770651349379114
# testing accuracy is  0.49399799554958745
#
#
# Random State is  116
# training accuracy is  0.4936234804316111
# testing accuracy is  0.5097367612520225
#
#
# Random State is  117
# training accuracy is  0.49600171941675697
# testing accuracy is  0.5015897199528281
#
#
# Random State is  118
# training accuracy is  0.5004923142811505
# testing accuracy is  0.4839941742434547
#
#
# Random State is  119
# training accuracy is  0.49802672737604303
# testing accuracy is  0.49133690200906743
#
#
# Random State is  120
# training accuracy is  0.4962791925098735
# testing accuracy is  0.49880733751685613
#
#
# Random State is  121
# training accuracy is  0.5025964991049139
# testing accuracy is  0.47462798698208786
#
#
# Random State is  122
# training accuracy is  0.49061664386244586
# testing accuracy is  0.5271181263606052
#
#
# Random State is  123
# training accuracy is  0.49564280613861345
# testing accuracy is  0.5025911930326287
#
#
# Random State is  124
# training accuracy is  0.4976643299260243
# testing accuracy is  0.49468823804769213
#
#
# Random State is  125
# training accuracy is  0.49526511114393934
# testing accuracy is  0.5025938807321355
#
#
# Random State is  126
# training accuracy is  0.49653173634472947
# testing accuracy is  0.4980141715735481
#
#
# Random State is  127
# training accuracy is  0.4938065331283271
# testing accuracy is  0.5113735882054572
#
#
# Random State is  128
# training accuracy is  0.4963289252732268
# testing accuracy is  0.499448822692105
#
#
# Random State is  129
# training accuracy is  0.498396366460345
# testing accuracy is  0.49217356890613984
#
#
# Random State is  130
# training accuracy is  0.4957659110755721
# testing accuracy is  0.5024740759464876
#
#
# Random State is  131
# training accuracy is  0.500636419304787
# testing accuracy is  0.4838671493165385
#
#
# Random State is  132
# training accuracy is  0.49609344395257016
# testing accuracy is  0.5014949407045697
#
#
# Random State is  133
# training accuracy is  0.5006691804268114
# testing accuracy is  0.48380130096080176
#
#
# Random State is  134
# training accuracy is  0.49446379149045283
# testing accuracy is  0.507286071947413
#
#
# Random State is  135
# training accuracy is  0.5012893137766385
# testing accuracy is  0.4808925652568188
#
#
# Random State is  136
# training accuracy is  0.4980995936754198
# testing accuracy is  0.4936052144149178
#
#
# Random State is  137
# training accuracy is  0.49600253714881326
# testing accuracy is  0.5020921982877721
#
#
# Random State is  138
# training accuracy is  0.49966464656398446
# testing accuracy is  0.48788273250384084
#
#
# Random State is  139
# training accuracy is  0.49761468884511684
# testing accuracy is  0.49399719287750965
#
#
# Random State is  140
# training accuracy is  0.4973890383047903
# testing accuracy is  0.4951277576197155
#
#
# Random State is  141
# training accuracy is  0.49774253961685433
# testing accuracy is  0.49417292636464005
#
#
# Random State is  142
# training accuracy is  0.49420759029827943
# testing accuracy is  0.5072160670525668
#
#
# Random State is  143
# training accuracy is  0.497425420823567
# testing accuracy is  0.4956610483875018
#
#
# Random State is  144
# training accuracy is  0.4950493292912418
# testing accuracy is  0.5046538190748129
#
#
# Random State is  145
# training accuracy is  0.500522199612411
# testing accuracy is  0.4827517227927267
#
#
# Random State is  146
# training accuracy is  0.49273975917394774
# testing accuracy is  0.5156387580808632
#
#
# Random State is  147
# training accuracy is  0.49268212185683313
# testing accuracy is  0.5162187889393607
#
#
# Random State is  148
# training accuracy is  0.5024488004001295
# testing accuracy is  0.47779043456975656
#
#
# Random State is  149
# training accuracy is  0.4955620419791975
# testing accuracy is  0.5028393976209735
#
#
# Random State is  150
# training accuracy is  0.4982773018376899
# testing accuracy is  0.4914347584995894
#
#
# Random State is  151
# training accuracy is  0.49149061143273565
# testing accuracy is  0.5193917476504215
#
#
# Random State is  152
# training accuracy is  0.4968295653155692
# testing accuracy is  0.49724599090585764
#
#
# Random State is  153
# training accuracy is  0.49950461068107865
# testing accuracy is  0.4879410896483206
#
#
# Random State is  154
# training accuracy is  0.49299871845043797
# testing accuracy is  0.51577843379003
#
#
# Random State is  155
# training accuracy is  0.4965517837318938
# testing accuracy is  0.4985843500589888
#
#
# Random State is  156
# training accuracy is  0.5048092713540722
# testing accuracy is  0.4635022603256941
#
#
# Random State is  157
# training accuracy is  0.4941562953444124
# testing accuracy is  0.5103890156664151
#
#
# Random State is  158
# training accuracy is  0.5037001941917134
# testing accuracy is  0.4727845790073222
#
#
# Random State is  159
# training accuracy is  0.4907973334930752
# testing accuracy is  0.5232298896843207
#
#
# Random State is  160
# training accuracy is  0.49680304520065355
# testing accuracy is  0.49854841254536997
#
#
# Random State is  161
# training accuracy is  0.4992305668000898
# testing accuracy is  0.4884072616724332
#
#
# Random State is  162
# training accuracy is  0.5019593242800231
# testing accuracy is  0.47924314428962456
#
#
# Random State is  163
# training accuracy is  0.5049347973476164
# testing accuracy is  0.46587616115948804
#
#
# Random State is  164
# training accuracy is  0.4985318572600145
# testing accuracy is  0.4911390933913977
#
#
# Random State is  165
# training accuracy is  0.5005039802116955
# testing accuracy is  0.4800355189386315
#
#
# Random State is  166
# training accuracy is  0.5019112458017345
# testing accuracy is  0.4796477587878525
#
#
# Random State is  167
# training accuracy is  0.5013913133953366
# testing accuracy is  0.4752502976707248
#
#
# Random State is  168
# training accuracy is  0.49731358038275797
# testing accuracy is  0.4959842963293588
#
#
# Random State is  169
# training accuracy is  0.5000473968966602
# testing accuracy is  0.4845293263698629
#
#
# Random State is  170
# training accuracy is  0.49702755030125767
# testing accuracy is  0.4958837777647406
#
#
# Random State is  171
# training accuracy is  0.4988132270023746
# testing accuracy is  0.4883375457905553
#
#
# Random State is  172
# training accuracy is  0.498404758447743
# testing accuracy is  0.4916494892839153
#
#
# Random State is  173
# training accuracy is  0.49774320967804697
# testing accuracy is  0.49401291576846407
#
#
# Random State is  174
# training accuracy is  0.49600172765245176
# testing accuracy is  0.5014216088340766
#
#
# Random State is  175
# training accuracy is  0.4976819580391838
# testing accuracy is  0.49518242474973706
#
#
# Random State is  176
# training accuracy is  0.49937717379447744
# testing accuracy is  0.48637957789964636
#
#
# Random State is  177
# training accuracy is  0.4987782591855928
# testing accuracy is  0.4884192307366435
#
#
# Random State is  178
# training accuracy is  0.49886638386707827
# testing accuracy is  0.49045020034817166
#
#
# Random State is  179
# training accuracy is  0.49983937211401286
# testing accuracy is  0.48287264974061406
#
#
# Random State is  180
# training accuracy is  0.4968525006666039
# testing accuracy is  0.4983569770459285
#
#
# Random State is  181
# training accuracy is  0.49036352171705466
# testing accuracy is  0.5281014201655903
#
#
# Random State is  182
# training accuracy is  0.4996537725102176
# testing accuracy is  0.48669124680648357
#
#
# Random State is  183
# training accuracy is  0.4995621499028542
# testing accuracy is  0.4870944126335345
#
#
# Random State is  184
# training accuracy is  0.49848128882915976
# testing accuracy is  0.49085639855910956
#
#
# Random State is  185
# training accuracy is  0.5022599092510216
# testing accuracy is  0.4788401768430208
#
#
# Random State is  186
# training accuracy is  0.49960155968774667
# testing accuracy is  0.4871087687096537
#
#
# Random State is  187
# training accuracy is  0.4963425392812013
# testing accuracy is  0.49873501185540425
#
#
# Random State is  188
# training accuracy is  0.49933752527010533
# testing accuracy is  0.48757022959368457
#
#
# Random State is  189
# training accuracy is  0.4957692337036348
# testing accuracy is  0.5004469666866209
#
#
# Random State is  190
# training accuracy is  0.5024646037643683
# testing accuracy is  0.4755818275569854
#
#
# Random State is  191
# training accuracy is  0.5027981481529298
# testing accuracy is  0.47271246016345614
#
#
# Random State is  192
# training accuracy is  0.49759262734889365
# testing accuracy is  0.49553222458511426
#
#
# Random State is  193
# training accuracy is  0.4956598454546729
# testing accuracy is  0.5028778334244763
#
#
# Random State is  194
# training accuracy is  0.5018018651762597
# testing accuracy is  0.47901431524724236
#
#
# Random State is  195
# training accuracy is  0.502152441795342
# testing accuracy is  0.47393046081568047
#
#
# Random State is  196
# training accuracy is  0.5010820195839963
# testing accuracy is  0.4698887494189917
#
#
# Random State is  197
# training accuracy is  0.5003105775089947
# testing accuracy is  0.48396839992153773
#
#
# Random State is  198
# training accuracy is  0.49962640488798526
# testing accuracy is  0.48439793483015525
#
#
# Random State is  199
# training accuracy is  0.497553595369014
# testing accuracy is  0.4949731798716033
#
#
# maximum r2 score is  0.5281014201655903 at random state  181

# %% [markdown]
# **I am selecting the maximum r2score 53% at random state 181**

# %%
# Spliting data on the best Random state we have got
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=181)

# %%
#running that same model again for other metrics too

lr.fit(x_train,y_train)
predtrainlr=lr.predict(x_train)
predtestlr=lr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainlr))
print('testing accuracy is ', r2_score(y_test,predtestlr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestlr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestlr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestlr)))
# Out:
# training accuracy is  0.49036352171705466
# testing accuracy is  0.5281014201655903
# Mean Squared Error is  9.271245211909632
# Mean Absolute Error is  1.4525298006334606
# Root Mean Squared Error is  3.044871953286317

# %%
from sklearn.model_selection import cross_val_score
#Cross validation of the lr model
for j in range(2,20):
    cv_score=cross_val_score(lr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
    print('training accuracy is ', r2_score(y_train,predtrainlr))
    print('testing accuracy is ', r2_score(y_test,predtestlr))
# Out:
# At fold  2 Mean CV score is  0.48732156011983774
# training accuracy is  0.49036352171705466
# testing accuracy is  0.5281014201655903
# At fold  3 Mean CV score is  0.4864743258717577
# training accuracy is  0.49036352171705466
# testing accuracy is  0.5281014201655903
# At fold  4 Mean CV score is  0.4813417178336086
# training accuracy is  0.49036352171705466
# testing accuracy is  0.5281014201655903
# At fold  5 Mean CV score is  0.491039024293291
# training accuracy is  0.49036352171705466
# testing accuracy is  0.5281014201655903
# At fold  6 Mean CV score is  0.48723142739648484
# training accuracy is  0.49036352171705466
# testing accuracy is  0.5281014201655903
# At fold  7 Mean CV score is  0.48744517767845935
# training accuracy is  0.49036352171705466
# testing accuracy is  0.5281014201655903
# At fold  8 Mean CV score is  0.4888936248350442
# training accuracy is  0.49036352171705466
# testing accuracy is  0.5281014201655903
# At fold  9 Mean CV score is  0.4884761423030953
# training accuracy is  0.49036352171705466
# testing accuracy is  0.5281014201655903
# At fold  10 Mean CV score is  0.4887158307712053
# training accuracy is  0.49036352171705466
# testing accuracy is  0.5281014201655903
# At fold  11 Mean CV score is  0.48612860655761164
# training accuracy is  0.49036352171705466
# testing accuracy is  0.5281014201655903
# At fold  12 Mean CV score is  0.4880036462046671
# training accuracy is  0.49036352171705466
# testing accuracy is  0.5281014201655903
# At fold  13 Mean CV score is  0.4892684547283407
# training accuracy is  0.49036352171705466
# testing accuracy is  0.5281014201655903
# At fold  14 Mean CV score is  0.48797850904265755
# training accuracy is  0.49036352171705466
# testing accuracy is  0.5281014201655903
# At fold  15 Mean CV score is  0.4839153783071248
# training accuracy is  0.49036352171705466
# testing accuracy is  0.5281014201655903
# At fold  16 Mean CV score is  0.4849086758089117
# training accuracy is  0.49036352171705466
# testing accuracy is  0.5281014201655903
# At fold  17 Mean CV score is  0.48591075924021726
# training accuracy is  0.49036352171705466
# testing accuracy is  0.5281014201655903
# At fold  18 Mean CV score is  0.48379983603570725
# training accuracy is  0.49036352171705466
# testing accuracy is  0.5281014201655903
# At fold  19 Mean CV score is  0.4871372929845238
# training accuracy is  0.49036352171705466
# testing accuracy is  0.5281014201655903

# %%
# modelling using the Decision tree regressor
from sklearn.tree import DecisionTreeRegressor

dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
predtraindtr=dtr.predict(x_train)
predtestdtr=dtr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtraindtr))
print('testing accuracy is ', r2_score(y_test,predtestdtr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestdtr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestdtr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestdtr)))
# Out:
# training accuracy is  1.0
# testing accuracy is  0.31817908276018037
# Mean Squared Error is  13.39552434456929
# Mean Absolute Error is  1.1136704119850187
# Root Mean Squared Error is  3.659989664544053

# %%
#Cross validation of the dtr model
dtr=DecisionTreeRegressor()
for j in range(2,10):
    cvdtr=cross_val_score(dtr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cvdtr.mean())
# Out:
# At fold  2 Mean CV score is  0.0798282370071195
# At fold  3 Mean CV score is  0.20096789455859462
# At fold  4 Mean CV score is  0.0725238101890511
# At fold  5 Mean CV score is  0.26617105667262797
# At fold  6 Mean CV score is  0.23347458369784932
# At fold  7 Mean CV score is  0.29515492327714793
# At fold  8 Mean CV score is  0.30066289422288733
# At fold  9 Mean CV score is  0.34971088476007456

# %%
# Modelling with randomForestRegressor

from sklearn.ensemble import RandomForestRegressor

rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
predtrainrfr=rfr.predict(x_train)
predtestrfr=rfr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainrfr))
print('testing accuracy is ', r2_score(y_test,predtestrfr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestrfr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestrfr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestrfr)))
# Out:
# training accuracy is  0.9508742886604088
# testing accuracy is  0.6804063740812165
# Mean Squared Error is  6.278956963795256
# Mean Absolute Error is  0.9577865168539325
# Root Mean Squared Error is  2.5057847002077525

# %%
#Cross validation of the rfr model
for j in range(2,10):
    cv_score=cross_val_score(rfr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  0.521493902480292
# At fold  3 Mean CV score is  0.5293633028900925
# At fold  4 Mean CV score is  0.49929574171251845
# At fold  5 Mean CV score is  0.5809198044342733
# At fold  6 Mean CV score is  0.576496003755981
# At fold  7 Mean CV score is  0.6022513370310875
# At fold  8 Mean CV score is  0.6169512863278307
# At fold  9 Mean CV score is  0.6404584206852911

# %%
# modelling with ExtraTreesRegressor

from sklearn.ensemble import ExtraTreesRegressor

etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
predtrainetr=etr.predict(x_train)
predtestetr=etr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainetr))
print('testing accuracy is ', r2_score(y_test,predtestetr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestetr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestetr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestetr)))
# Out:
# training accuracy is  1.0
# testing accuracy is  0.6842669710746682
# Mean Squared Error is  6.203109010611734
# Mean Absolute Error is  0.815011860174782
# Root Mean Squared Error is  2.490604145706767

# %%
#Cross validation of the etr model
for j in range(2,10):
    cv_score=cross_val_score(etr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  0.535439871611791
# At fold  3 Mean CV score is  0.5503054127645681
# At fold  4 Mean CV score is  0.5136865062261569
# At fold  5 Mean CV score is  0.6031048323816799
# At fold  6 Mean CV score is  0.6061001577054682
# At fold  7 Mean CV score is  0.6194312006870739
# At fold  8 Mean CV score is  0.6415272543298698
# At fold  9 Mean CV score is  0.6731699414726987

# %%
# Modeling for gradient boosting regresssor
from sklearn.ensemble import GradientBoostingRegressor

gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
predtraingbr=gbr.predict(x_train)
predtestgbr=gbr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtraingbr))
print('testing accuracy is ', r2_score(y_test,predtestgbr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestgbr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestgbr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestgbr)))
# Out:
# training accuracy is  0.6430230804513597
# testing accuracy is  0.5855439392752764
# Mean Squared Error is  8.142689833670133
# Mean Absolute Error is  1.1830696909355887
# Root Mean Squared Error is  2.8535398777080605

# %%
#Cross validation of the gbr model
for j in range(2,10):
    cv_score=cross_val_score(gbr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  0.4883146587835172
# At fold  3 Mean CV score is  0.488714982013919
# At fold  4 Mean CV score is  0.4768601331712542
# At fold  5 Mean CV score is  0.5200341908098305
# At fold  6 Mean CV score is  0.5160943617714981
# At fold  7 Mean CV score is  0.5257980163647443
# At fold  8 Mean CV score is  0.5333069187459871
# At fold  9 Mean CV score is  0.5391788516890379

# %%
from sklearn.linear_model import Lasso,Ridge
from sklearn.model_selection import GridSearchCV

# %%
# Doing Lasso Regularization
#HyperParameter Tunning to find out the best parameters
parameters={'alpha':[.00001,0.0001,0.001,0.01,0.1,1,10,100],
            'random_state':list(range(0,10)),
            'max_iter':[10,100,1000,10000],
            'tol': [0.001,0.0001,0.00001,0.000001]}

ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.01, 'max_iter': 100, 'random_state': 0, 'tol': 1e-06}

# %%
ls=Lasso(alpha=0.01, max_iter=100, random_state=0, tol=1e-06)
ls.fit(x_train,y_train)
predtrainls=ls.predict(x_train)
predtestls=ls.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainls))
print('testing accuracy is ', r2_score(y_test,predtestls))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestls))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestls))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestls)))
# Out:
# training accuracy is  0.49020727045905277
# testing accuracy is  0.5295401009232394
# Mean Squared Error is  9.242979896742753
# Mean Absolute Error is  1.433810739438945
# Root Mean Squared Error is  3.0402269482298117

# %%
#Cross validation of the ls model
for j in range(2,10):
    cv_score=cross_val_score(ls, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  0.4893455187343001
# At fold  3 Mean CV score is  0.48770523769649365
# At fold  4 Mean CV score is  0.48324681726674945
# At fold  5 Mean CV score is  0.49161860429810045
# At fold  6 Mean CV score is  0.48834415950225235
# At fold  7 Mean CV score is  0.4880668221034285
# At fold  8 Mean CV score is  0.4891990979018409
# At fold  9 Mean CV score is  0.48910256520266926

# %%
# Doing Ridge Regularization
#HyperParameter Tunning to find out the best parameters
parameters={'alpha':[.00001,0.0001,0.001,0.01,0.1,1,10,100],
            'random_state':list(range(0,10)),
            'max_iter':[10,100,1000,10000],
            'solver':['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs']}

rg=Ridge()
clf=GridSearchCV(rg,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 10, 'max_iter': 10, 'random_state': 5, 'solver': 'sag'}

# %%
rg=Ridge(alpha=10, max_iter=10, random_state=5, solver='sag')
rg.fit(x_train,y_train)
predtrainrg=rg.predict(x_train)
predtestrg=rg.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainrg))
print('testing accuracy is ', r2_score(y_test,predtestrg))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestrg))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestrg))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestrg)))
# Out:
# training accuracy is  0.48905110139359553
# testing accuracy is  0.5251887731286217
# Mean Squared Error is  9.328469085956792
# Mean Absolute Error is  1.4823849684273105
# Root Mean Squared Error is  3.0542542602011364

# %%
#Cross validation of the ls model
for j in range(2,10):
    cv_score=cross_val_score(rg, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  0.4827282790594343
# At fold  3 Mean CV score is  0.48637202019245757
# At fold  4 Mean CV score is  0.4814849779377494
# At fold  5 Mean CV score is  0.49126477565761223
# At fold  6 Mean CV score is  0.48631534639187546
# At fold  7 Mean CV score is  0.48713599091795795
# At fold  8 Mean CV score is  0.4890374112858298
# At fold  9 Mean CV score is  0.48826527387709956

# %% [markdown]
# **As we can see from the outputs of the each model Extra tree regressor is giving training and testing accuracy nearby hence I am selecting extra tree regressor**

# %% [markdown]
# **Hyper Parameter Tunning**

# %%
# modelling with ExtraTreesRegressor
from sklearn.ensemble import ExtraTreesRegressor

parameter = {
    'n_estimators': [200,300],
        'max_features': ['sqrt','log2'],
      'criterion':['mse','mae']
}

model = ExtraTreesRegressor ()

gcv = GridSearchCV(model,parameter,cv=9,n_jobs=-1).fit(x_train,y_train.values.ravel())

gcv.best_params_

# %%
# Checking score with best parameter
final_model=ExtraTreesRegressor(criterion='mse',max_features='sqrt',n_estimators=300)
final_model.fit(x_train,y_train)
predfinal=final_model.predict(x_test)
print('Final Accuracy is with Extra Tree Regressor = ',r2_score(y_test,predfinal))
# Out:
# Final Accuracy is with Extra Tree Regressor =  0.7123070837687597

# %%
#Importing Job lib for saving the model
import joblib
joblib.dump(ExtraTreesRegressor(criterion='mse',max_features='sqrt',n_estimators=300), "Rainfall Prediction in mm.pkl")
# Out:
# ['Rainfall Prediction in mm.pkl']

# %%
# Conclusion
a=np.array(y_test)
predicted=np.array(predfinal)
df_con=pd.DataFrame({'Original':a,'Predicted':predfinal}, index=range(len(a)))
df_con
# Out:
#       Original  Predicted
# 0          0.0   0.000000
# 1          0.0   0.011000
# 2          0.0   0.000000
# 3          0.0   0.000000
# 4          0.0   0.445000
# ...        ...        ...
# 1597       0.0   0.046667
# 1598       0.0   0.000000
# 1599       0.0   0.000000
# 1600       0.0   0.043333
# 1601       0.0   0.042667
#
# [1602 rows x 2 columns]

# %% [markdown]
# # Note:
# **To predict how much rainfall could be there, I have assumed the rainfall as a target variable but the model is not doing good,
# although for classification it is doing very good**
#
# I am wondering that there should be one column which is predicting the 'milimeter' of rain in the database which is missing, Hence I am not able to perform the regression analysis please consider this

# %% [markdown]
# # Classification model to Predict RainTomorrow

# %%
X=df.drop(['RainTomorrow'],axis=1)
Y=df['RainTomorrow']
print(X.shape)
print(Y.shape)
# Out:
# (8009, 21)
# (8009,)

# %%
# Removing Skewness Using Power Transform
from sklearn.preprocessing import power_transform
X=power_transform(X, method='yeo-johnson')
X
# Out:
# array([[-1.5682852 ,  0.06060344, -0.0734849 , ..., -2.40565137,
#          1.52477015, -1.88640618],
#        [-1.5682852 , -1.05556958,  0.28807299, ..., -2.40565137,
#          1.52477015, -1.70422725],
#        [-1.5682852 , -0.03191747,  0.38348436, ..., -2.40565137,
#          1.52477015, -1.53796992],
#        ...,
#        [ 1.01495158, -1.4313174 ,  0.57052254, ...,  1.67668156,
#         -0.04635331,  0.8352866 ],
#        [ 1.01495158, -0.98068825,  0.58588964, ...,  1.67668156,
#         -0.04635331,  0.93378743],
#        [ 1.01495158,  0.33772686, -0.00630683, ...,  1.67668156,
#         -0.04635331,  1.031236  ]])

# %%
#importing the StandardScaler
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
X=ss.fit_transform(X)
X
# Out:
# array([[-1.5682852 ,  0.06060344, -0.0734849 , ..., -2.40565137,
#          1.52477015, -1.88640618],
#        [-1.5682852 , -1.05556958,  0.28807299, ..., -2.40565137,
#          1.52477015, -1.70422725],
#        [-1.5682852 , -0.03191747,  0.38348436, ..., -2.40565137,
#          1.52477015, -1.53796992],
#        ...,
#        [ 1.01495158, -1.4313174 ,  0.57052254, ...,  1.67668156,
#         -0.04635331,  0.8352866 ],
#        [ 1.01495158, -0.98068825,  0.58588964, ...,  1.67668156,
#         -0.04635331,  0.93378743],
#        [ 1.01495158,  0.33772686, -0.00630683, ...,  1.67668156,
#         -0.04635331,  1.031236  ]])

# %%
# Checking the VIF score of the variables 
from statsmodels.stats.outliers_influence import variance_inflation_factor
new_df=pd.DataFrame(X)
def vif_scores(df):
    VIF_Scores = pd.DataFrame()
    VIF_Scores["Independent Features"] = new_df.columns
    VIF_Scores["VIF Scores"] = [variance_inflation_factor(new_df.values,i) for i in range(new_df.shape[1])]
    return VIF_Scores
df1 = new_df
vif_scores(df1)
# Out:
#     Independent Features  VIF Scores
# 0                      0    1.484453
# 1                      1    4.813991
# 2                      2    5.506090
# 3                      3    8.394698
# 4                      4    1.641711
# 5                      5    2.004741
# 6                      6    1.607510
# 7                      7    2.208596
# 8                      8    1.316716
# 9                      9    1.431375
# 10                    10    1.985688
# 11                    11    1.920163
# 12                    12    2.545262
# 13                    13    2.881888
# 14                    14    1.496299
# 15                    15    1.881099
# 16                    16    1.771819
# 17                    17    7.784556
# 18                    18    1.395882
# 19                    19    1.143053
# 20                    20    1.003305

# %% [markdown]
# As we can see that VIF scores of all input variables are less than 10 hence it is acceptable and moved further

# %% [markdown]
# **Balancing database**

# %%
Y.value_counts()
# Out:
# 0    6181
# 1    1828
# Name: RainTomorrow, dtype: int64

# %%
# Importing Libraries for it 
from imblearn.over_sampling import SMOTE
sm=SMOTE()
X,Y=sm.fit_resample(X,Y)
Y.value_counts()
# Out:
# 0    6181
# 1    6181
# Name: RainTomorrow, dtype: int64

# %%
# importing necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
lg=LogisticRegression()

# %%
# Finding the random state
maxaccu=0
maxrs=0
for i in range(1,100):
    print("At Random State ", i)
    Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y,test_size=.20, random_state=i)
    lg.fit(Xtrain,Ytrain)
    predlg=lg.predict(Xtest)
    trainlg=lg.predict(Xtrain)
    acc=accuracy_score(Ytest,predlg)
    accu=accuracy_score(Ytrain,trainlg)
    print('testing accuracy', acc, 'randon state',i)
    print('Training Accuracy', accu, 'random state', i)
    if acc>maxaccu:
        maxaccu=acc
        maxrs=i
        print('max accuracy', maxaccu , 'max_random_state', maxrs)
# Out:
# At Random State  1
# testing accuracy 0.7699150828952689 randon state 1
# Training Accuracy 0.773789058549904 random state 1
# max accuracy 0.7699150828952689 max_random_state 1
# At Random State  2
# testing accuracy 0.7731500202183583 randon state 2
# Training Accuracy 0.7733845687127111 random state 2
# max accuracy 0.7731500202183583 max_random_state 2
# At Random State  3
# testing accuracy 0.7695107157298827 randon state 3
# Training Accuracy 0.7732834462534128 random state 3
# At Random State  4
# testing accuracy 0.7816417306914678 randon state 4
# Training Accuracy 0.7689351805035899 random state 4
# max accuracy 0.7816417306914678 max_random_state 4
# At Random State  5
# testing accuracy 0.7836635665183987 randon state 5
# Training Accuracy 0.7688340580442916 random state 5
# max accuracy 0.7836635665183987 max_random_state 5
# At Random State  6
# testing accuracy 0.760614638091387 randon state 6
# Training Accuracy 0.7749014056021842 random state 6
# At Random State  7
# testing accuracy 0.7739587545491307 randon state 7
# Training Accuracy 0.7715643644453433 random state 7
# At Random State  8
# testing accuracy 0.772745653052972 randon state 8
# Training Accuracy 0.7709576296895541 random state 8
# At Random State  9
# testing accuracy 0.7699150828952689 randon state 9
# Training Accuracy 0.773789058549904 random state 9
# At Random State  10
# testing accuracy 0.7707238172260412 randon state 10
# Training Accuracy 0.7746991606835878 random state 10
# At Random State  11
# testing accuracy 0.7759805903760615 randon state 11
# Training Accuracy 0.7724744665790272 random state 11
# At Random State  12
# testing accuracy 0.7751718560452892 randon state 12
# Training Accuracy 0.7708565072302559 random state 12
# At Random State  13
# testing accuracy 0.770319450060655 randon state 13
# Training Accuracy 0.7732834462534128 random state 13
# At Random State  14
# testing accuracy 0.7711281843914274 randon state 14
# Training Accuracy 0.7726767114976236 random state 14
# At Random State  15
# testing accuracy 0.7707238172260412 randon state 15
# Training Accuracy 0.7734856911720093 random state 15
# At Random State  16
# testing accuracy 0.7715325515568136 randon state 16
# Training Accuracy 0.7731823237941147 random state 16
# At Random State  17
# testing accuracy 0.770319450060655 randon state 17
# Training Accuracy 0.7736879360906057 random state 17
# At Random State  18
# testing accuracy 0.7678932470683381 randon state 18
# Training Accuracy 0.7743957933056932 random state 18
# At Random State  19
# testing accuracy 0.7824504650222402 randon state 19
# Training Accuracy 0.7696430377186774 random state 19
# At Random State  20
# testing accuracy 0.7735543873837445 randon state 20
# Training Accuracy 0.7721710992011326 random state 20
# At Random State  21
# testing accuracy 0.7545491306105944 randon state 21
# Training Accuracy 0.7755081403579736 random state 21
# At Random State  22
# testing accuracy 0.7711281843914274 randon state 22
# Training Accuracy 0.7725755890383255 random state 22
# At Random State  23
# testing accuracy 0.7743631217145168 randon state 23
# Training Accuracy 0.7725755890383255 random state 23
# At Random State  24
# testing accuracy 0.7602102709260008 randon state 24
# Training Accuracy 0.7745980382242896 random state 24
# At Random State  25
# testing accuracy 0.7658714112414072 randon state 25
# Training Accuracy 0.7738901810092021 random state 25
# At Random State  26
# testing accuracy 0.7594015365952285 randon state 26
# Training Accuracy 0.7760137526544646 random state 26
# At Random State  27
# testing accuracy 0.7666801455721796 randon state 27
# Training Accuracy 0.7730812013348165 random state 27
# At Random State  28
# testing accuracy 0.7788111605337646 randon state 28
# Training Accuracy 0.770452017393063 random state 28
# At Random State  29
# testing accuracy 0.7828548321876264 randon state 29
# Training Accuracy 0.7702497724744666 random state 29
# At Random State  30
# testing accuracy 0.7784067933683785 randon state 30
# Training Accuracy 0.7711598746081505 random state 30
# At Random State  31
# testing accuracy 0.7614233724221593 randon state 31
# Training Accuracy 0.7761148751137628 random state 31
# At Random State  32
# testing accuracy 0.7598059037606146 randon state 32
# Training Accuracy 0.7766204874102538 random state 32
# At Random State  33
# testing accuracy 0.7804286291953093 randon state 33
# Training Accuracy 0.7689351805035899 random state 33
# At Random State  34
# testing accuracy 0.7808329963606955 randon state 34
# Training Accuracy 0.7706542623116595 random state 34
# At Random State  35
# testing accuracy 0.774767488879903 randon state 35
# Training Accuracy 0.7734856911720093 random state 35
# At Random State  36
# testing accuracy 0.7691063485644966 randon state 36
# Training Accuracy 0.7751036505207807 random state 36
# At Random State  37
# testing accuracy 0.7735543873837445 randon state 37
# Training Accuracy 0.7708565072302559 random state 37
# At Random State  38
# testing accuracy 0.7687019813991104 randon state 38
# Training Accuracy 0.772373344119729 random state 38
# At Random State  39
# testing accuracy 0.7780024262029923 randon state 39
# Training Accuracy 0.772373344119729 random state 39
# At Random State  40
# testing accuracy 0.7715325515568136 randon state 40
# Training Accuracy 0.7728789564162201 random state 40
# At Random State  41
# testing accuracy 0.7788111605337646 randon state 41
# Training Accuracy 0.7712609970674487 random state 41
# At Random State  42
# testing accuracy 0.7674888799029519 randon state 42
# Training Accuracy 0.7722722216604307 random state 42
# At Random State  43
# testing accuracy 0.7711281843914274 randon state 43
# Training Accuracy 0.7716654869046415 random state 43
# At Random State  44
# testing accuracy 0.7812373635260816 randon state 44
# Training Accuracy 0.7730812013348165 random state 44
# At Random State  45
# testing accuracy 0.7909421754953497 randon state 45
# Training Accuracy 0.7684295682070988 random state 45
# max accuracy 0.7909421754953497 max_random_state 45
# At Random State  46
# testing accuracy 0.77719369187222 randon state 46
# Training Accuracy 0.7725755890383255 random state 46
# At Random State  47
# testing accuracy 0.7585928022644561 randon state 47
# Training Accuracy 0.7751036505207807 random state 47
# At Random State  48
# testing accuracy 0.7646583097452487 randon state 48
# Training Accuracy 0.7731823237941147 random state 48
# At Random State  49
# testing accuracy 0.7800242620299231 randon state 49
# Training Accuracy 0.7711598746081505 random state 49
# At Random State  50
# testing accuracy 0.7654670440760211 randon state 50
# Training Accuracy 0.7722722216604307 random state 50
# At Random State  51
# testing accuracy 0.770319450060655 randon state 51
# Training Accuracy 0.7735868136313075 random state 51
# At Random State  52
# testing accuracy 0.7658714112414072 randon state 52
# Training Accuracy 0.7753058954393771 random state 52
# At Random State  53
# testing accuracy 0.7804286291953093 randon state 53
# Training Accuracy 0.769946405096572 random state 53
# At Random State  54
# testing accuracy 0.7634452082490901 randon state 54
# Training Accuracy 0.7725755890383255 random state 54
# At Random State  55
# testing accuracy 0.7650626769106349 randon state 55
# Training Accuracy 0.7763171200323592 random state 55
# At Random State  56
# testing accuracy 0.7691063485644966 randon state 56
# Training Accuracy 0.7738901810092021 random state 56
# At Random State  57
# testing accuracy 0.763040841083704 randon state 57
# Training Accuracy 0.7740924259277986 random state 57
# At Random State  58
# testing accuracy 0.7804286291953093 randon state 58
# Training Accuracy 0.7707553847709576 random state 58
# At Random State  59
# testing accuracy 0.7873028710068742 randon state 59
# Training Accuracy 0.7677217109920114 random state 59
# At Random State  60
# testing accuracy 0.770319450060655 randon state 60
# Training Accuracy 0.7721710992011326 random state 60
# At Random State  61
# testing accuracy 0.7893247068338051 randon state 61
# Training Accuracy 0.7695419152593791 random state 61
# At Random State  62
# testing accuracy 0.7646583097452487 randon state 62
# Training Accuracy 0.7732834462534128 random state 62
# At Random State  63
# testing accuracy 0.7735543873837445 randon state 63
# Training Accuracy 0.7710587521488522 random state 63
# At Random State  64
# testing accuracy 0.7763849575414477 randon state 64
# Training Accuracy 0.7721710992011326 random state 64
# At Random State  65
# testing accuracy 0.7731500202183583 randon state 65
# Training Accuracy 0.7698452826372737 random state 65
# At Random State  66
# testing accuracy 0.772745653052972 randon state 66
# Training Accuracy 0.774294670846395 random state 66
# At Random State  67
# testing accuracy 0.7682976142337242 randon state 67
# Training Accuracy 0.7741935483870968 random state 67
# At Random State  68
# testing accuracy 0.7614233724221593 randon state 68
# Training Accuracy 0.7753058954393771 random state 68
# At Random State  69
# testing accuracy 0.7759805903760615 randon state 69
# Training Accuracy 0.7702497724744666 random state 69
# At Random State  70
# testing accuracy 0.75818843509907 randon state 70
# Training Accuracy 0.7772272221660431 random state 70
# At Random State  71
# testing accuracy 0.7767893247068338 randon state 71
# Training Accuracy 0.7716654869046415 random state 71
# At Random State  72
# testing accuracy 0.7735543873837445 randon state 72
# Training Accuracy 0.7712609970674487 random state 72
# At Random State  73
# testing accuracy 0.77719369187222 randon state 73
# Training Accuracy 0.7689351805035899 random state 73
# At Random State  74
# testing accuracy 0.7674888799029519 randon state 74
# Training Accuracy 0.7727778339569218 random state 74
# At Random State  75
# testing accuracy 0.7670845127375657 randon state 75
# Training Accuracy 0.7762159975730609 random state 75
# At Random State  76
# testing accuracy 0.7775980590376061 randon state 76
# Training Accuracy 0.7714632419860451 random state 76
# At Random State  77
# testing accuracy 0.7678932470683381 randon state 77
# Training Accuracy 0.7732834462534128 random state 77
# At Random State  78
# testing accuracy 0.7828548321876264 randon state 78
# Training Accuracy 0.7686318131256952 random state 78
# At Random State  79
# testing accuracy 0.7759805903760615 randon state 79
# Training Accuracy 0.7709576296895541 random state 79
# At Random State  80
# testing accuracy 0.7573797007682976 randon state 80
# Training Accuracy 0.7752047729800788 random state 80
# At Random State  81
# testing accuracy 0.7666801455721796 randon state 81
# Training Accuracy 0.7720699767418343 random state 81
# At Random State  82
# testing accuracy 0.7650626769106349 randon state 82
# Training Accuracy 0.7752047729800788 random state 82
# At Random State  83
# testing accuracy 0.7775980590376061 randon state 83
# Training Accuracy 0.7719688542825361 random state 83
# At Random State  84
# testing accuracy 0.7626364739183178 randon state 84
# Training Accuracy 0.7754070178986753 random state 84
# At Random State  85
# testing accuracy 0.7868985038414881 randon state 85
# Training Accuracy 0.7675194660734149 random state 85
# At Random State  86
# testing accuracy 0.7646583097452487 randon state 86
# Training Accuracy 0.7753058954393771 random state 86
# At Random State  87
# testing accuracy 0.7804286291953093 randon state 87
# Training Accuracy 0.770452017393063 random state 87
# At Random State  88
# testing accuracy 0.763040841083704 randon state 88
# Training Accuracy 0.7760137526544646 random state 88
# At Random State  89
# testing accuracy 0.770319450060655 randon state 89
# Training Accuracy 0.7735868136313075 random state 89
# At Random State  90
# testing accuracy 0.7695107157298827 randon state 90
# Training Accuracy 0.7735868136313075 random state 90
# At Random State  91
# testing accuracy 0.7602102709260008 randon state 91
# Training Accuracy 0.7748002831428861 random state 91
# At Random State  92
# testing accuracy 0.7662757784067934 randon state 92
# Training Accuracy 0.7741935483870968 random state 92
# At Random State  93
# testing accuracy 0.7731500202183583 randon state 93
# Training Accuracy 0.7733845687127111 random state 93
# At Random State  94
# testing accuracy 0.7638495754144763 randon state 94
# Training Accuracy 0.7738901810092021 random state 94
# At Random State  95
# testing accuracy 0.7719369187221997 randon state 95
# Training Accuracy 0.771867731823238 random state 95
# At Random State  96
# testing accuracy 0.7687019813991104 randon state 96
# Training Accuracy 0.7739913034685003 random state 96
# At Random State  97
# testing accuracy 0.7638495754144763 randon state 97
# Training Accuracy 0.7734856911720093 random state 97
# At Random State  98
# testing accuracy 0.7832591993530126 randon state 98
# Training Accuracy 0.769946405096572 random state 98
# At Random State  99
# testing accuracy 0.7800242620299231 randon state 99
# Training Accuracy 0.7714632419860451 random state 99

# %%
# Checking for the Max. Accuracy at Random State
print('max accuracy', maxaccu , 'max_random_state', maxrs)
# Out:
# max accuracy 0.7909421754953497 max_random_state 45

# %%
# train test split for the data with suggested random state
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=.20,random_state=45)

# %%
# Checking score again for the the lr model 
lg=LogisticRegression()
lg.fit(X_train,Y_train)
predlg=lg.predict(X_test)
predtrain=lg.predict(X_train)
print("Training accuracy is ",accuracy_score(Y_train,predtrain))
print(accuracy_score(Y_test,predlg))
print(confusion_matrix(Y_test,predlg))
print(classification_report(Y_test,predlg))
# Out:
# Training accuracy is  0.7684295682070988
# 0.7909421754953497
# [[988 266]
#  [251 968]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.79      1254
#            1       0.78      0.79      0.79      1219
#
#     accuracy                           0.79      2473
#    macro avg       0.79      0.79      0.79      2473
# weighted avg       0.79      0.79      0.79      2473

# %%
#AUC ROC Curve
# Importing libraries
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
#AUC ROC curve for Decision Tree Classifier
Y_pred_prob=lg.predict_proba(X_test)[:,1]
fpr,tpr,threshold=roc_curve(Y_test,Y_pred_prob,pos_label=1)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Linear Regression')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Logistic Regression')
plt.show()

auc_score=roc_auc_score(Y_test,lg.predict(X_test))

auc_score
# Out:
# 0.7909861535784423

# %%
# using DecisionTreeClassifier 
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(X_train,Y_train)
preddtc=dtc.predict(X_test)
predtrain=dtc.predict(X_train)
print("Training accuracy is ",accuracy_score(Y_train,predtrain))
print(accuracy_score(Y_test,preddtc))
print(confusion_matrix(Y_test,preddtc))
print(classification_report(Y_test,preddtc))
# Out:
# Training accuracy is  1.0
# 0.8847553578649414
# [[1090  164]
#  [ 121 1098]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.88      1254
#            1       0.87      0.90      0.89      1219
#
#     accuracy                           0.88      2473
#    macro avg       0.89      0.88      0.88      2473
# weighted avg       0.89      0.88      0.88      2473

# %%
#AUC ROC curve for Decision Tree Classifier
Y_pred_prob=dtc.predict_proba(X_test)[:,1]
fpr,tpr,threshold=roc_curve(Y_test,Y_pred_prob,pos_label=1)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Decision Tree Classifier')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Decision Tree Classifier')
plt.show()

auc_score=roc_auc_score(Y_test,dtc.predict(X_test))

auc_score
# Out:
# 0.8849784054438431

# %%
# Using RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
predrf=rf.predict(X_test)
predtrain=rf.predict(X_train)
print("Training accuracy is ",accuracy_score(Y_train,predtrain))
print(accuracy_score(Y_test,predrf))
print(confusion_matrix(Y_test,predrf))
print(classification_report(Y_test,predrf))
# Out:
# Training accuracy is  1.0
# 0.9393449251920744
# [[1177   77]
#  [  73 1146]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      1254
#            1       0.94      0.94      0.94      1219
#
#     accuracy                           0.94      2473
#    macro avg       0.94      0.94      0.94      2473
# weighted avg       0.94      0.94      0.94      2473

# %%
#AUC ROC curve for Random Forest Classifier Classifier
Y_pred_prob=rf.predict_proba(X_test)[:,1]
fpr,tpr,threshold=roc_curve(Y_test,Y_pred_prob,pos_label=1)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Random Forest Classifier')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Random Forest Classifier')
plt.show()

auc_score=roc_auc_score(Y_test,rf.predict(X_test))

auc_score
# Out:
# 0.9393556697321649

# %%
# Using SVC
from sklearn.svm import SVC
svc=SVC(probability=True)
svc.fit(X_train,Y_train)
predsvc=svc.predict(X_test)
predtrain=svc.predict(X_train)
print("Training accuracy is ",accuracy_score(Y_train,predtrain))
print(accuracy_score(Y_test,predsvc))
print(confusion_matrix(Y_test,predsvc))
print(classification_report(Y_test,predsvc))
# Out:
# Training accuracy is  0.8871473354231975
# 0.8641326324302466
# [[1050  204]
#  [ 132 1087]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86      1254
#            1       0.84      0.89      0.87      1219
#
#     accuracy                           0.86      2473
#    macro avg       0.87      0.86      0.86      2473
# weighted avg       0.87      0.86      0.86      2473

# %%
#AUC ROC curve for  SVC
Y_pred_prob=svc.predict_proba(X_test)[:,1]
fpr,tpr,threshold=roc_curve(Y_test,Y_pred_prob,pos_label=1)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='SVC')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('SVC')
plt.show()

auc_score=roc_auc_score(Y_test,svc.predict(X_test))

auc_score
# Out:
# 0.8645175471305604

# %%
# Using KNN
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
predknn=knn.predict(X_test)
predtrain=knn.predict(X_train)
print("Training accuracy is ",accuracy_score(Y_train,predtrain))
print(accuracy_score(Y_test,predknn))
print(confusion_matrix(Y_test,predknn))
print(classification_report(Y_test,predknn))
# Out:
# Training accuracy is  0.9082819294165234
# 0.8637282652648605
# [[ 952  302]
#  [  35 1184]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.76      0.85      1254
#            1       0.80      0.97      0.88      1219
#
#     accuracy                           0.86      2473
#    macro avg       0.88      0.87      0.86      2473
# weighted avg       0.88      0.86      0.86      2473

# %%
#AUC ROC curve for  KNeighborsClassifier
Y_pred_prob=knn.predict_proba(X_test)[:,1]
fpr,tpr,threshold=roc_curve(Y_test,Y_pred_prob,pos_label=1)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='KNeighborsClassifier')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('KNeighborsClassifier')
plt.show()

auc_score=roc_auc_score(Y_test,knn.predict(X_test))

auc_score
# Out:
# 0.8652292974213444

# %%
# Using GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingClassifier
xgb=GradientBoostingClassifier()
xgb.fit(X_train,Y_train)
predxgb=xgb.predict(X_test)
predtrain=knn.predict(X_train)
print("Training accuracy is ",accuracy_score(Y_train,predtrain))
print(accuracy_score(Y_test,predxgb))
print(confusion_matrix(Y_test,predxgb))
print(classification_report(Y_test,predxgb))
# Out:
# Training accuracy is  0.9082819294165234
# 0.8669632025879499
# [[1095  159]
#  [ 170 1049]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87      1254
#            1       0.87      0.86      0.86      1219
#
#     accuracy                           0.87      2473
#    macro avg       0.87      0.87      0.87      2473
# weighted avg       0.87      0.87      0.87      2473

# %%
#AUC ROC curve for  GradientBoostingClassifier
Y_pred_prob=xgb.predict_proba(X_test)[:,1]
fpr,tpr,threshold=roc_curve(Y_test,Y_pred_prob,pos_label=1)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='GradientBoostingClassifier')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('GradientBoostingClassifier')
plt.show()

auc_score=roc_auc_score(Y_test,xgb.predict(X_test))

auc_score
# Out:
# 0.8668735845131509

# %%
# using AdaBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
ada=AdaBoostClassifier()
ada.fit(X_train,Y_train)
predada=ada.predict(X_test)
predtrain=ada.predict(X_train)
print("Training accuracy is ",accuracy_score(Y_train,predtrain))
print(accuracy_score(Y_test,predada))
print(confusion_matrix(Y_test,predada))
print(classification_report(Y_test,predada))
# Out:
# Training accuracy is  0.8267772272221661
# 0.8257177517185604
# [[1037  217]
#  [ 214 1005]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83      1254
#            1       0.82      0.82      0.82      1219
#
#     accuracy                           0.83      2473
#    macro avg       0.83      0.83      0.83      2473
# weighted avg       0.83      0.83      0.83      2473

# %%
#AUC ROC curve for  AdaBoostClassifier
Y_pred_prob=ada.predict_proba(X_test)[:,1]
fpr,tpr,threshold=roc_curve(Y_test,Y_pred_prob,pos_label=1)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='AdaBoostClassifier')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('AdaBoostClassifier')
plt.show()

auc_score=roc_auc_score(Y_test,ada.predict(X_test))

auc_score
# Out:
# 0.8257000077193505

# %%
# Using Naive bayes (GaussianNB)
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, Y_train)
predgnb = gnb.predict(X_test)
predtrain=gnb.predict(X_train)
print("Training accuracy is ",accuracy_score(Y_train,predtrain))
print(accuracy_score(Y_test,predgnb))
print(confusion_matrix(Y_test,predgnb))
print(classification_report(Y_test,predgnb))
# Out:
# Training accuracy is  0.7402164020628982
# 0.7569753336029115
# [[930 324]
#  [277 942]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.74      0.76      1254
#            1       0.74      0.77      0.76      1219
#
#     accuracy                           0.76      2473
#    macro avg       0.76      0.76      0.76      2473
# weighted avg       0.76      0.76      0.76      2473

# %%
#AUC ROC curve for  GaussianNB
Y_pred_prob=gnb.predict_proba(X_test)[:,1]
fpr,tpr,threshold=roc_curve(Y_test,Y_pred_prob,pos_label=1)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label=' GaussianNB')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title(' GaussianNB')
plt.show()

auc_score=roc_auc_score(Y_test,gnb.predict(X_test))

auc_score
# Out:
# 0.7571956776870209

# %%
from sklearn.model_selection import cross_val_score

# validation accuracy

model=[lg,dtc,rf,knn,xgb,ada,gnb]

for i in model:
    for j in range(11,21):
        print('taking cv =', j)
        cr_score=cross_val_score(i, X, Y, cv=j)
        print('Cross validation score for ' , i ,' is', cr_score)
        print('Mean of Cross Val. score is ', cr_score.mean())
# Out:
# taking cv = 11
# Cross validation score for  LogisticRegression()  is [0.80071174 0.66014235 0.58718861 0.82295374 0.66281139 0.71975089
#  0.70996441 0.69572954 0.79181495 0.83348175 0.82813891]
# Mean of Cross Val. score is  0.7375171158734187
# taking cv = 12
# Cross validation score for  LogisticRegression()  is [0.81183317 0.65179437 0.65145631 0.7776699  0.66504854 0.68834951
#  0.71165049 0.70582524 0.74271845 0.80679612 0.83203883 0.83203883]
# Mean of Cross Val. score is  0.739768314923457
# taking cv = 13
# Cross validation score for  LogisticRegression()  is [0.82334385 0.65930599 0.68874869 0.72870662 0.77707676 0.66140904
#  0.70872766 0.69295478 0.7150368  0.76235542 0.80967403 0.84016824
#  0.84      ]
# Mean of Cross Val. score is  0.7467313758796408
# taking cv = 14
# Cross validation score for  LogisticRegression()  is [0.83125708 0.68629672 0.70781427 0.60588901 0.83578709 0.66477916
#  0.67270668 0.71574179 0.72706682 0.6817667  0.79048698 0.81653454
#  0.8403171  0.83578709]
# Mean of Cross Val. score is  0.7437307878983984
# taking cv = 15
# Cross validation score for  LogisticRegression()  is [0.82424242 0.71030303 0.68325243 0.61165049 0.83009709 0.69902913
#  0.68082524 0.69417476 0.70145631 0.72936893 0.73665049 0.77791262
#  0.83131068 0.83980583 0.83616505]
# Mean of Cross Val. score is  0.7457496322447779
# taking cv = 16
# Cross validation score for  LogisticRegression()  is [0.82535576 0.70245796 0.67658473 0.6610608  0.7606727  0.79042691
#  0.64683053 0.68175938 0.71280724 0.7076326  0.71373057 0.76165803
#  0.78626943 0.83678756 0.83937824 0.83160622]
# Mean of Cross Val. score is  0.7459386667247585
# taking cv = 17
# Cross validation score for  LogisticRegression()  is [0.8282967  0.7032967  0.69917582 0.63686382 0.70701513 0.82806052
#  0.66299862 0.72077029 0.68363136 0.72489684 0.72764787 0.68363136
#  0.7647868  0.81568088 0.83081155 0.84731774 0.82393398]
# Mean of Cross Val. score is  0.7464009410768858
# taking cv = 18
# Cross validation score for  LogisticRegression()  is [0.82823872 0.72780204 0.66666667 0.70742358 0.60407569 0.86608443
#  0.72052402 0.66084425 0.68122271 0.72634643 0.6783115  0.74090247
#  0.70742358 0.80786026 0.81341108 0.83527697 0.85276968 0.81924198]
# Mean of Cross Val. score is  0.746912558604921
# taking cv = 19
# Cross validation score for  LogisticRegression()  is [0.82488479 0.73271889 0.67588326 0.7296467  0.62672811 0.79723502
#  0.79262673 0.65130568 0.7311828  0.67281106 0.74500768 0.72043011
#  0.70461538 0.75076923 0.78153846 0.82       0.84923077 0.85846154
#  0.81538462]
# Mean of Cross Val. score is  0.7516032015522679
# taking cv = 20
# Cross validation score for  LogisticRegression()  is [0.82067851 0.75928918 0.6763754  0.72491909 0.65857605 0.72815534
#  0.82524272 0.69902913 0.66666667 0.68608414 0.72977346 0.67799353
#  0.74757282 0.68608414 0.77831715 0.78964401 0.8171521  0.8592233
#  0.84951456 0.81877023]
# Mean of Cross Val. score is  0.7499530770477489
# taking cv = 11
# Cross validation score for  DecisionTreeClassifier()  is [0.60320285 0.76245552 0.59519573 0.71085409 0.96708185 0.95462633
#  0.95729537 0.94839858 0.75355872 0.87177204 0.83526269]
# Mean of Cross Val. score is  0.8145185243229058
# taking cv = 12
# Cross validation score for  DecisionTreeClassifier()  is [0.60911736 0.78370514 0.63398058 0.63980583 0.96213592 0.9631068
#  0.9631068  0.9631068  0.90873786 0.74368932 0.86407767 0.84368932]
# Mean of Cross Val. score is  0.8231882829690594
# taking cv = 13
# Cross validation score for  DecisionTreeClassifier()  is [0.61093586 0.76656151 0.73922187 0.65720294 0.84121977 0.96109359
#  0.96529968 0.96109359 0.96950578 0.86645636 0.76656151 0.89064143
#  0.84736842]
# Mean of Cross Val. score is  0.8340894094007161
# taking cv = 14
# Cross validation score for  DecisionTreeClassifier()  is [0.61494904 0.77123443 0.77689694 0.56738392 0.81087203 0.96375991
#  0.96828992 0.9592299  0.9603624  0.9592299  0.81766704 0.81087203
#  0.89014723 0.85503964]
# Mean of Cross Val. score is  0.8375667367739846
# taking cv = 15
# Cross validation score for  DecisionTreeClassifier()  is [0.59636364 0.76484848 0.83737864 0.64563107 0.6881068  0.93932039
#  0.9538835  0.96966019 0.95509709 0.97087379 0.94174757 0.75242718
#  0.88713592 0.85800971 0.84223301]
# Mean of Cross Val. score is  0.8401811317054036
# taking cv = 16
# Cross validation score for  DecisionTreeClassifier()  is [0.58861578 0.72315653 0.81888745 0.6610608  0.60931436 0.87839586
#  0.95601552 0.9702458  0.96636481 0.95989651 0.97020725 0.89766839
#  0.72279793 0.87953368 0.87435233 0.83678756]
# Mean of Cross Val. score is  0.8320812861538048
# taking cv = 17
# Cross validation score for  DecisionTreeClassifier()  is [0.57142857 0.61675824 0.8228022  0.73452545 0.62861073 0.76066025
#  0.96148556 0.96836314 0.9656121  0.97111417 0.96286107 0.96286107
#  0.81980743 0.75790922 0.89133425 0.87207703 0.85832187]
# Mean of Cross Val. score is  0.8309724905727819
# taking cv = 18
# Cross validation score for  DecisionTreeClassifier()  is [0.55749636 0.62736536 0.76710335 0.76273654 0.61280932 0.69286754
#  0.95196507 0.95924309 0.9636099  0.95633188 0.9650655  0.97525473
#  0.93740902 0.8224163  0.71720117 0.86734694 0.89358601 0.8425656 ]
# Mean of Cross Val. score is  0.826242980730103
# taking cv = 19
# Cross validation score for  DecisionTreeClassifier()  is [0.67741935 0.68049155 0.79262673 0.79262673 0.65437788 0.71121352
#  0.88632873 0.97081413 0.96466974 0.96774194 0.97235023 0.95698925
#  0.96923077 0.91846154 0.80153846 0.78615385 0.90307692 0.88307692
#  0.84      ]
# Mean of Cross Val. score is  0.8489046437433535
# taking cv = 20
# Cross validation score for  DecisionTreeClassifier()  is [0.65589661 0.68174475 0.83656958 0.84466019 0.68608414 0.64724919
#  0.72815534 0.95631068 0.96278317 0.96601942 0.96440129 0.96278317
#  0.97249191 0.96763754 0.86245955 0.72815534 0.8802589  0.90453074
#  0.87702265 0.83333333]
# Mean of Cross Val. score is  0.8459273752947387
# taking cv = 11
# Cross validation score for  RandomForestClassifier()  is [0.8113879  0.79893238 0.53558719 0.76067616 0.98754448 0.9866548
#  0.9911032  0.97419929 0.80338078 0.95725735 0.92965272]
# Mean of Cross Val. score is  0.8669432958639868
# taking cv = 12
# Cross validation score for  RandomForestClassifier()  is [0.82929195 0.81377304 0.68058252 0.65436893 0.98834951 0.98834951
#  0.9815534  0.99029126 0.95339806 0.82038835 0.95145631 0.91941748]
# Mean of Cross Val. score is  0.8809350271047368
# taking cv = 13
# Cross validation score for  RandomForestClassifier()  is [0.85068349 0.83280757 0.829653   0.69926393 0.89905363 0.9873817
#  0.98948475 0.9873817  0.99053628 0.89169295 0.8338591  0.93901157
#  0.93157895]
# Mean of Cross Val. score is  0.897106817030443
# taking cv = 14
# Cross validation score for  RandomForestClassifier()  is [0.85390713 0.8391846  0.87655719 0.57757644 0.83238958 0.98640997
#  0.98527746 0.98754247 0.98980747 0.98640997 0.86749717 0.90713477
#  0.93771234 0.93657984]
# Mean of Cross Val. score is  0.897427600711859
# taking cv = 15
# Cross validation score for  RandomForestClassifier()  is [0.85939394 0.83272727 0.88349515 0.62135922 0.74271845 0.98907767
#  0.98179612 0.98907767 0.98665049 0.99029126 0.96601942 0.89563107
#  0.97330097 0.9368932  0.9211165 ]
# Mean of Cross Val. score is  0.9046365597724821
# taking cv = 16
# Cross validation score for  RandomForestClassifier()  is [0.85899094 0.80336352 0.85510996 0.71280724 0.75808538 0.91073739
#  0.98965071 0.98965071 0.98318241 0.98706339 0.99093264 0.94430052
#  0.78756477 0.96761658 0.94689119 0.92098446]
# Mean of Cross Val. score is  0.9004332382079108
# taking cv = 17
# Cross validation score for  RandomForestClassifier()  is [0.87087912 0.78846154 0.84752747 0.76203576 0.69876204 0.85006878
#  0.98624484 0.98762036 0.99037139 0.99037139 0.99174691 0.99037139
#  0.87207703 0.80192572 0.95323246 0.9394773  0.92572215]
# Mean of Cross Val. score is  0.8968762142461472
# taking cv = 18
# Cross validation score for  RandomForestClassifier()  is [0.87190684 0.78893741 0.81222707 0.87336245 0.59679767 0.73799127
#  0.98544396 0.98981077 0.98689956 0.98835517 0.98835517 0.99272198
#  0.97525473 0.90247453 0.80612245 0.96209913 0.95626822 0.91107872]
# Mean of Cross Val. score is  0.8958948381459746
# taking cv = 19
# Cross validation score for  RandomForestClassifier()  is [0.87250384 0.78341014 0.82642089 0.9078341  0.65130568 0.81259601
#  0.92012289 0.99078341 0.99078341 0.98771121 0.98924731 0.98771121
#  0.98923077 0.96461538 0.88307692 0.92307692 0.96461538 0.94923077
#  0.92307692]
# Mean of Cross Val. score is  0.91143964128684
# taking cv = 20
# Cross validation score for  RandomForestClassifier()  is [0.86914378 0.79321486 0.86893204 0.89320388 0.7184466  0.7184466
#  0.85275081 0.98867314 0.99029126 0.98705502 0.98867314 0.98543689
#  0.99352751 0.98705502 0.94174757 0.89967638 0.96601942 0.97249191
#  0.95307443 0.91423948]
# Mean of Cross Val. score is  0.914104987164808
# taking cv = 11
# Cross validation score for  KNeighborsClassifier()  is [0.77491103 0.72686833 0.54982206 0.70729537 0.84519573 0.87900356
#  0.86120996 0.83807829 0.77046263 0.85930543 0.81923419]
# Mean of Cross Val. score is  0.7846715091900681
# taking cv = 12
# Cross validation score for  KNeighborsClassifier()  is [0.79534433 0.75654704 0.67184466 0.67281553 0.84757282 0.8631068
#  0.86796117 0.86796117 0.83592233 0.8        0.85728155 0.81941748]
# Mean of Cross Val. score is  0.8046479052291581
# taking cv = 13
# Cross validation score for  KNeighborsClassifier()  is [0.81177708 0.78654048 0.76656151 0.68664564 0.83070452 0.84963197
#  0.87592008 0.84858044 0.86855941 0.78233438 0.8212408  0.84963197
#  0.82421053]
# Mean of Cross Val. score is  0.8155645240254239
# taking cv = 14
# Cross validation score for  KNeighborsClassifier()  is [0.81993205 0.799547   0.78029445 0.63080408 0.74292186 0.84824462
#  0.85503964 0.87542469 0.86862967 0.84371461 0.75764439 0.8403171
#  0.84258211 0.81993205]
# Mean of Cross Val. score is  0.8089305937550557
# taking cv = 15
# Cross validation score for  KNeighborsClassifier()  is [0.8230303  0.79878788 0.77427184 0.60072816 0.68567961 0.8592233
#  0.86529126 0.86650485 0.86043689 0.87985437 0.85679612 0.77305825
#  0.8907767  0.83616505 0.81796117]
# Mean of Cross Val. score is  0.8125710503089144
# taking cv = 16
# Cross validation score for  KNeighborsClassifier()  is [0.82535576 0.78525226 0.73997413 0.63518758 0.72186287 0.84476067
#  0.84864166 0.8538163  0.87968952 0.85899094 0.8626943  0.83937824
#  0.76295337 0.88471503 0.85492228 0.80699482]
# Mean of Cross Val. score is  0.8128243578615045
# taking cv = 17
# Cross validation score for  KNeighborsClassifier()  is [0.82692308 0.77472527 0.74038462 0.71526823 0.71114168 0.77579092
#  0.85006878 0.88033012 0.8610729  0.87345254 0.88445667 0.85419532
#  0.76616231 0.80742779 0.85419532 0.87070151 0.79779917]
# Mean of Cross Val. score is  0.8143586023976832
# taking cv = 18
# Cross validation score for  KNeighborsClassifier()  is [0.82678311 0.77583697 0.73071325 0.78020378 0.643377   0.6783115
#  0.88209607 0.84279476 0.8573508  0.87481805 0.8558952  0.8937409
#  0.85152838 0.7874818  0.80612245 0.86734694 0.8819242  0.78571429]
# Mean of Cross Val. score is  0.8123355254626978
# taking cv = 19
# Cross validation score for  KNeighborsClassifier()  is [0.83870968 0.79262673 0.76190476 0.81259601 0.65591398 0.7235023
#  0.85867896 0.83717358 0.90168971 0.85253456 0.88632873 0.88940092
#  0.85538462 0.86615385 0.77384615 0.82923077 0.89076923 0.88307692
#  0.77538462]
# Mean of Cross Val. score is  0.8255213716673817
# taking cv = 20
# Cross validation score for  KNeighborsClassifier()  is [0.84975767 0.81260097 0.79288026 0.80582524 0.67313916 0.73462783
#  0.78802589 0.86084142 0.85436893 0.86731392 0.88187702 0.85598706
#  0.88834951 0.85275081 0.83171521 0.77831715 0.88834951 0.89967638
#  0.87378641 0.76860841]
# Mean of Cross Val. score is  0.8279399386211187
# taking cv = 11
# Cross validation score for  GradientBoostingClassifier()  is [0.67704626 0.60142349 0.44661922 0.78736655 0.79003559 0.83896797
#  0.8247331  0.82740214 0.7544484  0.89492431 0.89047195]
# Mean of Cross Val. score is  0.757585360422195
# taking cv = 12
# Cross validation score for  GradientBoostingClassifier()  is [0.7129001  0.628516   0.59805825 0.54271845 0.81941748 0.82135922
#  0.83009709 0.82330097 0.85048544 0.78543689 0.89029126 0.8815534 ]
# Mean of Cross Val. score is  0.765344545622907
# taking cv = 13
# Cross validation score for  GradientBoostingClassifier()  is [0.73817035 0.65299685 0.67928496 0.60988433 0.83070452 0.78128286
#  0.829653   0.80231335 0.83911672 0.8212408  0.79284963 0.88958991
#  0.88947368]
# Mean of Cross Val. score is  0.781273920058579
# taking cv = 14
# Cross validation score for  GradientBoostingClassifier()  is [0.77236693 0.68403171 0.71574179 0.46885617 0.81653454 0.80747452
#  0.81879955 0.83691959 0.83465459 0.81426954 0.82785957 0.84824462
#  0.90600227 0.88674972]
# Mean of Cross Val. score is  0.7884646497330529
# taking cv = 15
# Cross validation score for  GradientBoostingClassifier()  is [0.77333333 0.69090909 0.70509709 0.5461165  0.73786408 0.83373786
#  0.80218447 0.81067961 0.82038835 0.84223301 0.85558252 0.81917476
#  0.89805825 0.89320388 0.88349515]
# Mean of Cross Val. score is  0.7941371972148672
# taking cv = 16
# Cross validation score for  GradientBoostingClassifier()  is [0.79560155 0.68175938 0.62871928 0.60931436 0.61578266 0.85252264
#  0.78913325 0.81112549 0.81759379 0.82664942 0.84326425 0.88082902
#  0.73445596 0.91321244 0.90414508 0.87564767]
# Mean of Cross Val. score is  0.7862347634544102
# taking cv = 17
# Cross validation score for  GradientBoostingClassifier()  is [0.78434066 0.6717033  0.65659341 0.6258597  0.59697387 0.81430536
#  0.83218707 0.82806052 0.79917469 0.84456671 0.8431912  0.82118294
#  0.82530949 0.76066025 0.91196699 0.89408528 0.88445667]
# Mean of Cross Val. score is  0.7879187120832886
# taking cv = 18
# Cross validation score for  GradientBoostingClassifier()  is [0.7874818  0.66229985 0.59534207 0.72052402 0.48908297 0.81950509
#  0.84716157 0.79039301 0.83114993 0.82532751 0.80349345 0.86026201
#  0.83260553 0.86171761 0.73906706 0.91253644 0.91253644 0.87609329]
# Mean of Cross Val. score is  0.7870322038845344
# taking cv = 19
# Cross validation score for  GradientBoostingClassifier()  is [0.77880184 0.66359447 0.63133641 0.74654378 0.53763441 0.79416283
#  0.86175115 0.79416283 0.85253456 0.78801843 0.85099846 0.84178187
#  0.83076923 0.86923077 0.82923077 0.89076923 0.92153846 0.92
#  0.86923077]
# Mean of Cross Val. score is  0.8037942250166359
# taking cv = 20
# Cross validation score for  GradientBoostingClassifier()  is [0.79644588 0.69466882 0.67475728 0.73624595 0.61650485 0.60355987
#  0.82038835 0.84951456 0.79126214 0.83656958 0.83171521 0.81229773
#  0.86407767 0.82038835 0.89805825 0.83171521 0.91423948 0.93042071
#  0.90614887 0.86084142]
# Mean of Cross Val. score is  0.8044910101374491
# taking cv = 11
# Cross validation score for  AdaBoostClassifier()  is [0.73487544 0.54626335 0.38345196 0.67704626 0.74466192 0.79270463
#  0.78736655 0.77758007 0.73042705 0.84683882 0.83526269]
# Mean of Cross Val. score is  0.7142253398183276
# taking cv = 12
# Cross validation score for  AdaBoostClassifier()  is [0.74393792 0.62269641 0.53009709 0.63300971 0.75048544 0.79708738
#  0.7815534  0.79029126 0.81262136 0.76796117 0.86699029 0.83883495]
# Mean of Cross Val. score is  0.7446305312026218
# taking cv = 13
# Cross validation score for  AdaBoostClassifier()  is [0.76971609 0.65720294 0.61724501 0.66771819 0.80231335 0.75604627
#  0.79390116 0.77287066 0.79284963 0.78338591 0.75920084 0.86119874
#  0.85578947]
# Mean of Cross Val. score is  0.7607260203408301
# taking cv = 14
# Cross validation score for  AdaBoostClassifier()  is [0.78708947 0.69082673 0.65911665 0.51415629 0.75424689 0.74178935
#  0.75084938 0.78255946 0.80634202 0.76783692 0.78822197 0.84484711
#  0.86070215 0.84258211]
# Mean of Cross Val. score is  0.7565118912797282
# taking cv = 15
# Cross validation score for  AdaBoostClassifier()  is [0.79636364 0.66060606 0.67961165 0.52791262 0.67718447 0.77305825
#  0.76213592 0.77548544 0.76334951 0.7961165  0.79975728 0.77184466
#  0.89320388 0.8276699  0.84830097]
# Mean of Cross Val. score is  0.7568400509953909
# taking cv = 16
# Cross validation score for  AdaBoostClassifier()  is [0.78525226 0.65976714 0.64165589 0.56015524 0.72186287 0.77360931
#  0.71927555 0.77231565 0.77231565 0.8007762  0.78367876 0.83160622
#  0.70595855 0.86139896 0.85880829 0.83937824]
# Mean of Cross Val. score is  0.7554884240795232
# taking cv = 17
# Cross validation score for  AdaBoostClassifier()  is [0.78296703 0.61675824 0.64423077 0.58734525 0.64511692 0.76891334
#  0.74415406 0.78541953 0.76066025 0.7909216  0.81568088 0.78129298
#  0.80330124 0.73177442 0.86795048 0.86519945 0.82806052]
# Mean of Cross Val. score is  0.7541027626795084
# taking cv = 18
# Cross validation score for  AdaBoostClassifier()  is [0.79767103 0.6055313  0.63318777 0.66957787 0.55167394 0.67248908
#  0.79184862 0.73653566 0.74526929 0.79039301 0.75836972 0.80931587
#  0.7860262  0.84425036 0.71282799 0.86005831 0.8819242  0.83090379]
# Mean of Cross Val. score is  0.7487696679836418
# taking cv = 19
# Cross validation score for  AdaBoostClassifier()  is [0.78801843 0.60368664 0.64976959 0.68970814 0.56989247 0.78187404
#  0.82642089 0.72196621 0.8218126  0.7296467  0.79569892 0.78187404
#  0.78769231 0.82769231 0.79538462 0.86769231 0.90153846 0.88
#  0.81538462]
# Mean of Cross Val. score is  0.770302804156794
# taking cv = 20
# Cross validation score for  AdaBoostClassifier()  is [0.78998384 0.61712439 0.6407767  0.68608414 0.60355987 0.65210356
#  0.80906149 0.76860841 0.72168285 0.77346278 0.79126214 0.76699029
#  0.82038835 0.77669903 0.85113269 0.75728155 0.88349515 0.88996764
#  0.87702265 0.7961165 ]
# Mean of Cross Val. score is  0.7636402015987788
# taking cv = 11
# Cross validation score for  GaussianNB()  is [0.7411032  0.72864769 0.68683274 0.78736655 0.64857651 0.68950178
#  0.65302491 0.6316726  0.81494662 0.77916296 0.81300089]
# Mean of Cross Val. score is  0.7248942222457813
# taking cv = 12
# Cross validation score for  GaussianNB()  is [0.74587779 0.71096023 0.72524272 0.75631068 0.6592233  0.6776699
#  0.66893204 0.63980583 0.71456311 0.80097087 0.78058252 0.81553398]
# Mean of Cross Val. score is  0.7246394143995681
# taking cv = 13
# Cross validation score for  GaussianNB()  is [0.75078864 0.70767613 0.75078864 0.72975815 0.75604627 0.63617245
#  0.68138801 0.6298633  0.64563617 0.77497371 0.78864353 0.77707676
#  0.83368421]
# Mean of Cross Val. score is  0.7278843067386982
# taking cv = 14
# Cross validation score for  GaussianNB()  is [0.77349943 0.70781427 0.7599094  0.67723669 0.79048698 0.64439411
#  0.6783692  0.66704417 0.67723669 0.60928652 0.801812   0.79614949
#  0.77010193 0.83238958]
# Mean of Cross Val. score is  0.7275521760232972
# taking cv = 15
# Cross validation score for  GaussianNB()  is [0.77333333 0.70181818 0.75970874 0.67961165 0.79368932 0.71237864
#  0.65048544 0.66868932 0.64927184 0.66990291 0.69538835 0.7973301
#  0.80218447 0.76941748 0.8276699 ]
# Mean of Cross Val. score is  0.7300586446994214
# taking cv = 16
# Cross validation score for  GaussianNB()  is [0.77490298 0.68693402 0.75291074 0.72574386 0.7606727  0.75937904
#  0.62613195 0.68693402 0.67529107 0.64812419 0.63212435 0.75518135
#  0.80699482 0.78497409 0.78497409 0.82253886]
# Mean of Cross Val. score is  0.7302382590204372
# taking cv = 17
# Cross validation score for  GaussianNB()  is [0.78021978 0.68681319 0.75824176 0.72352132 0.72764787 0.77579092
#  0.66024759 0.69050894 0.65749656 0.67400275 0.68363136 0.60522696
#  0.80467675 0.81430536 0.77303989 0.79642366 0.8170564 ]
# Mean of Cross Val. score is  0.7311088862589792
# taking cv = 18
# Cross validation score for  GaussianNB()  is [0.77874818 0.70305677 0.71906841 0.78020378 0.65647744 0.80931587
#  0.73362445 0.62736536 0.67540029 0.68122271 0.62154294 0.6783115
#  0.65502183 0.81950509 0.79883382 0.78571429 0.80029155 0.81632653]
# Mean of Cross Val. score is  0.7300017116432765
# taking cv = 19
# Cross validation score for  GaussianNB()  is [0.77880184 0.70353303 0.71121352 0.79109063 0.67281106 0.78955453
#  0.76036866 0.62826421 0.69892473 0.64823349 0.70660522 0.66973886
#  0.61692308 0.73692308 0.79538462 0.79076923 0.80307692 0.80307692
#  0.81076923]
# Mean of Cross Val. score is  0.7324243611510164
# taking cv = 20
# Cross validation score for  GaussianNB()  is [0.77544426 0.71082391 0.72977346 0.76537217 0.71197411 0.74919094
#  0.77184466 0.70550162 0.63268608 0.68446602 0.68932039 0.61326861
#  0.69417476 0.60841424 0.78478964 0.802589   0.77831715 0.8171521
#  0.79126214 0.81391586]
# Mean of Cross Val. score is  0.7315140559729388

# %% [markdown]
# **Observation and Model selection on the basis of above results**
#
# 1. We can see that the Random Forest Classifier is giving accuracy of almost 94%, higher than the rest of the Classifiers.
# 2. If consider the cross val score of all the classifiers at fold 20 the Random Forest Classifier is giving the score of 91.41%
# 3. Hence I am selecting the Random Forest Classifier for the given prediction

# %% [markdown]
# **Hyperparameter Tunning**

# %%
from sklearn.model_selection import GridSearchCV

#Creating parameter list to be passed in GridSearchCV
parameters = {
    'n_estimators':[200,300],
    'max_features':['auto','log2'],
    'max_depth':[40,50]
 
}     

GCV=GridSearchCV(estimator=RandomForestClassifier(),
                param_grid=parameters,
                cv=20,
                scoring='accuracy')

# %%
GCV.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=20, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [40, 50],
#                          'max_features': ['auto', 'log2'],
#                          'n_estimators': [200, 300]},
#              scoring='accuracy')

# %%
GCV.best_params_
# Out:
# {'max_depth': 50, 'max_features': 'auto', 'n_estimators': 200}

# %%
# Checking score with best parameter
final_model=RandomForestClassifier(max_depth=50,max_features='auto',n_estimators=200)
final_model.fit(X_train,Y_train)
predfinal=final_model.predict(X_test)
print('Final Accuracy is with Random Forest Classifier = ',accuracy_score(Y_test,predfinal))
# Out:
# Final Accuracy is with Random Forest Classifier =  0.9437929640113223

# %%
#AUC ROC of Best Estimator
from sklearn.metrics import plot_roc_curve
plot_roc_curve(GCV.best_estimator_,X_test,Y_test)
plt.title('AUC ROC Curve')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Finalizing and Saving the model**

# %%
# Saving the Model
import joblib
joblib.dump(GCV.best_estimator_, "Weather Forecasting Rain Prediction.pkl")
# Out:
# ['Weather Forecasting Rain Prediction.pkl']

# %%
# Conclusion
a=np.array(Y_test)
predicted=np.array(predfinal)
df_con=pd.DataFrame({'Original':a,'Predicted':predicted}, index=range(len(a)))
df_con
# Out:
#       Original  Predicted
# 0            1          1
# 1            1          1
# 2            1          1
# 3            0          0
# 4            1          1
# ...        ...        ...
# 2468         1          1
# 2469         1          1
# 2470         0          0
# 2471         0          0
# 2472         0          0
#
# [2473 rows x 2 columns]
